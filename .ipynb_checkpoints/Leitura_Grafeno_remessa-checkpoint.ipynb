# %%
#ler o corpo da Remessa

import os
pasta =  'C:/Users/elean/Desktop/BANCOS/grafeno'


# Liste todos os arquivos na pasta
arquivos = os.listdir(pasta)

# Filtrar apenas os arquivos que têm a extensão .REM
arquivos_rem = [arquivo for arquivo in arquivos if arquivo.endswith('.REM')]

# Encontre o arquivo REM mais recente com base na data de modificação
if arquivos_rem:
    caminho_arquivo_rem = max(arquivos_rem, key=lambda arquivo: os.path.getmtime(os.path.join(pasta, arquivo)))
    
    # Crie o caminho completo para o arquivo REM mais recente
    cnab = os.path.join(pasta, caminho_arquivo_rem)

# Defina o caminho para o arquivo CNAB do Santander
arquivo_cnab =  cnab

# Crie uma lista para armazenar os registros lidos
cabecario = []

with open(arquivo_cnab, 'r') as arquivo:
    # Leia cada linha do arquivo
    linhas = arquivo.readlines()

    for linha in linhas[1:]:      # Faça algo com cada linha do arquivo, por exemplo, imprima-a
                campo1 = linha[0:1]
                campo2 = linha[20:37]
                campo3 = linha[37:62]
                campo4 = linha[62:65]    
                campo5 = linha[65:66]        
                campo6 = linha[66:70]        
                campo7 = linha[70:81]        
                campo8 = linha[81:82]        
                campo9 = linha[82:92]        
                campo10 = linha[106:108]        
                campo11 = linha[108:110]  
                campo12 = linha[110:120]        
                campo13 = linha[120:126]        
                campo14 = linha[126:139]        
                campo15 = linha[139:142]        
                campo16 = linha[142:147]        
                campo17 = linha[149:150]        
                campo18 = linha[150:156]        
                campo19 = linha[160:173]        
                campo20 = linha[173:179]        
                campo21 = linha[179:192]        
                campo22 = linha[192:205]   
                campo23 = linha[205:218]        
                campo24 = linha[220:234]        
                campo25 = linha[234:274]        
                campo26 = linha[274:314]        
                campo27 = linha[394:400]        

                registro = {
                'Identificação do registro': campo1,
                'Identificação da empresa beneficiária no banco': campo2,   
                 'Número de controle do participante': campo3,     
                  'Código do banco a ser debitado na câmara de compensação': campo4,     
                 'Campo de multa': campo5,   
                 'Percentual multa': campo6,             
                 'Identificação do título no banco': campo7,             
                 'Dígito de auto conferência do número bancário': campo8,             
                 'Desconto': campo9,             
                 'Quantidade de pagamentos possíveis': campo10,             
                 'Identificação da ocorrência': campo11,             
                 'CODIGO DO DOC': campo12,             
                 'Data do vencimento': campo13,             
                  'Valor': campo14,             
                 'Banco': campo15,             
                 'Agência depositária': campo16,             
                 'Identificação': campo17,             
                 'Data da emissão do título': campo18,             
                 'Valor a ser cobrado por dia de atraso': campo19,             
                 'desconto ate': campo20,            
                 'Valor do desconto': campo21,             
                 'Valor do IOF': campo22,             
                 'Valor do abatimento a ser concedido ou cancelado': campo23,             
                 'cnpj pagador': campo24,             
                 'Cliente': campo25,             
                 'endereco': campo26,             
                 'Número sequencial do registro': campo27,             





 }
        
                cabecario.append(registro)

for registro in cabecario:
    print(registro)
# Out:
# {'Identificação do registro': '1', 'Identificação da empresa beneficiária no banco': '00010000181400665', 'Número de controle do participante': 'E418719                  ', 'Código do banco a ser debitado na câmara de compensação': '000', 'Campo de multa': '0', 'Percentual multa': '0000', 'Identificação do título no banco': '00000000321', 'Dígito de auto conferência do número bancário': '6', 'Desconto': '0000000000', 'Quantidade de pagamentos possíveis': '  ', 'Identificação da ocorrência': '02', 'CODIGO DO DOC': '418719    ', 'Data do vencimento': '231224', 'Valor': '0000000061812', 'Banco': '000', 'Agência depositária': '00000', 'Identificação': 'N', 'Data da emissão do título': '181124', 'Valor a ser cobrado por dia de atraso': '0000000000000', 'desconto ate': '000000', 'Valor do desconto': '0000000000000', 'Valor do IOF': '0000000000000', 'Valor do abatimento a ser concedido ou cancelado': '0000000000000', 'cnpj pagador':
 'Banco': '000', 'Agência depositária': '00000', 'Identificação': 'N', 'Data da emissão do título': '131224', 'Valor a ser cobrado por dia de atraso': '0000000000020', 'desconto ate': '000000', 'Valor do desconto': '0000000000000', 'Valor do IOF': '0000000000000', 'Valor do abatimento a ser concedido ou cancelado': '0000000000000', 'cnpj pagador': '06017533000162', 'Cliente': '2C FARMACIA SAUDE E HOMEOPATIA LTDA     ', 'endereco': 'RUA AUGUSTO EMMEL SALA A 49             ', 'Número sequencial do registro': '000021'}
# {'Identificação do registro': '1', 'Identificação da empresa beneficiária no banco': '00010000181400665', 'Número de controle do participante': 'W419933                  ', 'Código do banco a ser debitado na câmara de compensação': '000', 'Campo de multa': '2', 'Percentual multa': '0500', 'Identificação do título no banco': '00000001535', 'Dígito de auto conferência do número bancário': '4', 'Desconto': '0000000000', 'Quantidade de pagamentos possíveis': '  ', 'Identificação da ocorrência': '01', 'CODIGO DO DOC': '419933    ', 'Data do vencimento': '030125', 'Valor': '0000000004681', 'Banco': '000', 'Agência depositária': '00000', 'Identificação': 'N', 'Data da emissão do título': '131224', 'Valor a ser cobrado por dia de atraso': '0000000000003', 'desconto ate': '000000', 'Valor do desconto': '0000000000000', 'Valor do IOF': '0000000000000', 'Valor do abatimento a ser concedido ou cancelado': '0000000000000', 'cnpj pagador': '14904859000130', 'Cliente': 'DROGARIA TIO TONI LTDA                  ', 'endereco': 'RUA CONEGO PEDRO JACOBS SALA 04 877     ', 'Número sequencial do registro': '000022'}
# {'Identificação do registro': '1', 'Identificação da empresa beneficiária no banco': '00010000181400665', 'Número de controle do participante': 'L419934                  ', 'Código do banco a ser debitado na câmara de compensação': '000', 'Campo de multa': '2', 'Percentual multa': '0500', 'Identificação do título no banco': '00000001536', 'Dígito de auto conferência do número bancário': '2', 'Desconto': '0000000000', 'Quantidade de pagamentos possíveis': '  ', 'Identificação da ocorrência': '01', 'CODIGO DO DOC': '419934    ', 'Data do vencimento': '100125', 'Valor': '0000000025081', 'Banco': '000', 'Agência depositária': '00000', 'Identificação': 'N', 'Data da emissão do título': '131224', 'Valor a ser cobrado por dia de atraso': '0000000000016', 'desconto ate': '000000', 'Valor do desconto': '0000000000000', 'Valor do IOF': '0000000000000', 'Valor do abatimento a ser concedido ou cancelado': '0000000000000', 'cnpj pagador': '14904859000130', 'Cliente': 'DROGARIA TIO TONI LTDA                  ', 'endereco': 'RUA CONEGO PEDRO JACOBS SALA 04 877     ', 'Número sequencial do registro': '000023'}
# {'Identificação do registro': '1', 'Identificação da empresa beneficiária no banco': '00010000181400665', 'Número de controle do participante': 'F419935                  ', 'Código do banco a ser debitado na câmara de compensação': '000', 'Campo de multa': '2', 'Percentual multa': '0500', 'Identificação do título no banco': '00000001537', 'Dígito de auto conferência do número bancário': '0', 'Desconto': '0000000000', 'Quantidade de pagamentos possíveis': '  ', 'Identificação da ocorrência': '01', 'CODIGO DO DOC': '419935    ', 'Data do vencimento': '240125', 'Valor': '0000000025082', 'Banco': '000', 'Agência depositária': '00000', 'Identificação': 'N', 'Data da emissão do título': '131224', 'Valor a ser cobrado por dia de atraso': '0000000000016', 'desconto ate': '000000', 'Valor do desconto': '0000000000000', 'Valor do IOF': '0000000000000', 'Valor do abatimento a ser concedido ou cancelado': '0000000000000', 'cnpj pagador': '14904859000130', 'Cliente': 'DROGARIA TIO TONI LTDA                  ', 'endereco': 'RUA CONEGO PEDRO JACOBS SALA 04 877     ', 'Número sequencial do registro': '000024'}
# {'Identificação do registro': '1', 'Identificação da empresa beneficiária no banco': '00010000181400665', 'Número de controle do participante': 'U419936                  ', 'Código do banco a ser debitado na câmara de compensação': '000', 'Campo de multa': '2', 'Percentual multa': '0500', 'Identificação do título no banco': '00000001538', 'Dígito de auto conferência do número bancário': '9', 'Desconto': '0000000000', 'Quantidade de pagamentos possíveis': '  ', 'Identificação da ocorrência': '01', 'CODIGO DO DOC': '419936    ', 'Data do vencimento': '030125', 'Valor': '0000000001153', 'Banco': '000', 'Agência depositária': '00000', 'Identificação': 'N', 'Data da emissão do título': '131224', 'Valor a ser cobrado por dia de atraso': '0000000000000', 'desconto ate': '000000', 'Valor do desconto': '0000000000000', 'Valor do IOF': '0000000000000', 'Valor do abatimento a ser concedido ou cancelado': '0000000000000', 'cnpj pagador': '04959362000165', 'Cliente': 'FARMACIA CASAGRANDE LTDA                ', 'endereco': 'RUA ICARO 778 999728517 ROSI            ', 'Número sequencial do registro': '000025'}
# {'Identificação do registro': '1', 'Identificação da empresa beneficiária no banco': '00010000181400665', 'Número de controle do participante': 'T419937                  ', 'Código do banco a ser debitado na câmara de compensação': '000', 'Campo de multa': '2', 'Percentual multa': '0500', 'Identificação do título no banco': '00000001539', 'Dígito de auto conferência do número bancário': '7', 'Desconto': '0000000000', 'Quantidade de pagamentos possíveis': '  ', 'Identificação da ocorrência': '01', 'CODIGO DO DOC': '419937    ', 'Data do vencimento': '240125', 'Valor': '0000000031501', 'Banco': '000', 'Agência depositária': '00000', 'Identificação': 'N', 'Data da emissão do título': '131224', 'Valor a ser cobrado por dia de atraso': '0000000000021', 'desconto ate': '000000', 'Valor do desconto': '0000000000000', 'Valor do IOF': '0000000000000', 'Valor do abatimento a ser concedido ou cancelado': '0000000000000', 'cnpj pagador': '04959362000165', 'Cliente': 'FARMACIA CASAGRANDE LTDA                ', 'endereco': 'RUA ICARO 778 999728517 ROSI            ', 'Número sequencial do registro': '000026'}
# {'Identificação do registro': '1', 'Identificação da empresa beneficiária no banco': '00010000181400665', 'Número de controle do participante': 'T419938                  ', 'Código do banco a ser debitado na câmara de compensação': '000', 'Campo de multa': '2', 'Percentual multa': '0500', 'Identificação do título no banco': '00000001540', 'Dígito de auto conferência do número bancário': '0', 'Desconto': '0000000000', 'Quantidade de pagamentos possíveis': '  ', 'Identificação da ocorrência': '01', 'CODIGO DO DOC': '419938    ', 'Data do vencimento': '030125', 'Valor': '0000000136387', 'Banco': '000', 'Agência depositária': '00000', 'Identificação': 'N', 'Data da emissão do título': '131224', 'Valor a ser cobrado por dia de atraso': '0000000000090', 'desconto ate': '000000', 'Valor do desconto': '0000000000000', 'Valor do IOF': '0000000000000', 'Valor do abatimento a ser concedido ou cancelado': '0000000000000', 'cnpj pagador': '22968133000199', 'Cliente': 'FARMACIA BRASIL LTDA                    ', 'endereco': 'AV URUGUAI 1499                         ', 'Número sequencial do registro': '000027'}
# {'Identificação do registro': '1', 'Identificação da empresa beneficiária no banco': '00010000181400665', 'Número de controle do participante': 'U419939                  ', 'Código do banco a ser debitado na câmara de compensação': '000', 'Campo de multa': '2', 'Percentual multa': '0500', 'Identificação do título no banco': '00000001541', 'Dígito de auto conferência do número bancário': '9', 'Desconto': '0000000000', 'Quantidade de pagamentos possíveis': '  ', 'Identificação da ocorrência': '01', 'CODIGO DO DOC': '419939    ', 'Data do vencimento': '110225', 'Valor': '0000000268022', 'Banco': '000', 'Agência depositária': '00000', 'Identificação': 'N', 'Data da emissão do título': '131224', 'Valor a ser cobrado por dia de atraso': '0000000000178', 'desconto ate': '000000', 'Valor do desconto': '0000000000000', 'Valor do IOF': '0000000000000', 'Valor do abatimento a ser concedido ou cancelado': '0000000000000', 'cnpj pagador': '22968133000199', 'Cliente': 'FARMACIA BRASIL LTDA                    ', 'endereco': 'AV URUGUAI 1499                         ', 'Número sequencial do registro': '000028'}
# {'Identificação do registro': '1', 'Identificação da empresa beneficiária no banco': '00010000181400665', 'Número de controle do participante': 'P419940                  ', 'Código do banco a ser debitado na câmara de compensação': '000', 'Campo de multa': '2', 'Percentual multa': '0500', 'Identificação do título no banco': '00000001542', 'Dígito de auto conferência do número bancário': '7', 'Desconto': '0000000000', 'Quantidade de pagamentos possíveis': '  ', 'Identificação da ocorrência': '01', 'CODIGO DO DOC': '419940    ', 'Data do vencimento': '140225', 'Valor': '0000000268022', 'Banco': '000', 'Agência depositária': '00000', 'Identificação': 'N', 'Data da emissão do título': '131224', 'Valor a ser cobrado por dia de atraso': '0000000000178', 'desconto ate': '000000', 'Valor do desconto': '0000000000000', 'Valor do IOF': '0000000000000', 'Valor do abatimento a ser concedido ou cancelado': '0000000000000', 'cnpj pagador': '22968133000199', 'Cliente': 'FARMACIA BRASIL LTDA                    ', 'endereco': 'AV URUGUAI 1499                         ', 'Número sequencial do registro': '000029'}
# {'Identificação do registro': '1', 'Identificação da empresa beneficiária no banco': '00010000181400665', 'Número de controle do participante': 'C419941                  ', 'Código do banco a ser debitado na câmara de compensação': '000', 'Campo de multa': '2', 'Percentual multa': '0500', 'Identificação do título no banco': '00000001543', 'Dígito de auto conferência do número bancário': '5', 'Desconto': '0000000000', 'Quantidade de pagamentos possíveis': '  ', 'Identificação da ocorrência': '01', 'CODIGO DO DOC': '419941    ', 'Data do vencimento': '170225', 'Valor': '0000000268022', 'Banco': '000', 'Agência depositária': '00000', 'Identificação': 'N', 'Data da emissão do título': '131224', 'Valor a ser cobrado por dia de atraso': '0000000000178', 'desconto ate': '000000', 'Valor do desconto': '0000000000000', 'Valor do IOF': '0000000000000', 'Valor do abatimento a ser concedido ou cancelado': '0000000000000', 'cnpj pagador': '22968133000199', 'Cliente': 'FARMACIA BRASIL LTDA                    ', 'endereco': 'AV URUGUAI 1499                         ', 'Número sequencial do registro': '000030'}
# {'Identificação do registro': '1', 'Identificação da empresa beneficiária no banco': '00010000181400665', 'Número de controle do participante': 'V419942                  ', 'Código do banco a ser debitado na câmara de compensação': '000', 'Campo de multa': '2', 'Percentual multa': '0500', 'Identificação do título no banco': '00000001544', 'Dígito de auto conferência do número bancário': '3', 'Desconto': '0000000000', 'Quantidade de pagamentos possíveis': '  ', 'Identificação da ocorrência': '01', 'CODIGO DO DOC': '419942    ', 'Data do vencimento': '200225', 'Valor': '0000000268022', 'Banco': '000', 'Agência depositária': '00000', 'Identificação': 'N', 'Data da emissão do título': '131224', 'Valor a ser cobrado por dia de atraso': '0000000000178', 'desconto ate': '000000', 'Valor do desconto': '0000000000000', 'Valor do IOF': '0000000000000', 'Valor do abatimento a ser concedido ou cancelado': '0000000000000', 'cnpj pagador': '22968133000199', 'Cliente': 'FARMACIA BRASIL LTDA                    ', 'endereco': 'AV URUGUAI 1499                         ', 'Número sequencial do registro': '000031'}
# {'Identificação do registro': '1', 'Identificação da empresa beneficiária no banco': '00010000181400665', 'Número de controle do participante': 'V419943                  ', 'Código do banco a ser debitado na câmara de compensação': '000', 'Campo de multa': '2', 'Percentual multa': '0500', 'Identificação do título no banco': '00000001545', 'Dígito de auto conferência do número bancário': '1', 'Desconto': '0000000000', 'Quantidade de pagamentos possíveis': '  ', 'Identificação da ocorrência': '01', 'CODIGO DO DOC': '419943    ', 'Data do vencimento': '240225', 'Valor': '0000000268022', 'Banco': '000', 'Agência depositária': '00000', 'Identificação': 'N', 'Data da emissão do título': '131224', 'Valor a ser cobrado por dia de atraso': '0000000000178', 'desconto ate': '000000', 'Valor do desconto': '0000000000000', 'Valor do IOF': '0000000000000', 'Valor do abatimento a ser concedido ou cancelado': '0000000000000', 'cnpj pagador': '22968133000199', 'Cliente': 'FARMACIA BRASIL LTDA                    ', 'endereco': 'AV URUGUAI 1499                         ', 'Número sequencial do registro': '000032'}
# {'Identificação do registro': '1', 'Identificação da empresa beneficiária no banco': '00010000181400665', 'Número de controle do participante': 'M419944                  ', 'Código do banco a ser debitado na câmara de compensação': '000', 'Campo de multa': '2', 'Percentual multa': '0500', 'Identificação do título no banco': '00000001546', 'Dígito de auto conferência do número bancário': 'P', 'Desconto': '0000000000', 'Quantidade de pagamentos possíveis': '  ', 'Identificação da ocorrência': '01', 'CODIGO DO DOC': '419944    ', 'Data do vencimento': '260225', 'Valor': '0000000268022', 'Banco': '000', 'Agência depositária': '00000', 'Identificação': 'N', 'Data da emissão do título': '131224', 'Valor a ser cobrado por dia de atraso': '0000000000178', 'desconto ate': '000000', 'Valor do desconto': '0000000000000', 'Valor do IOF': '0000000000000', 'Valor do abatimento a ser concedido ou cancelado': '0000000000000', 'cnpj pagador': '22968133000199', 'Cliente': 'FARMACIA BRASIL LTDA                    ', 'endereco': 'AV URUGUAI 1499                         ', 'Número sequencial do registro': '000033'}
# {'Identificação do registro': '1', 'Identificação da empresa beneficiária no banco': '00010000181400665', 'Número de controle do participante': 'Z419945                  ', 'Código do banco a ser debitado na câmara de compensação': '000', 'Campo de multa': '2', 'Percentual multa': '0500', 'Identificação do título no banco': '00000001547', 'Dígito de auto conferência do número bancário': '8', 'Desconto': '0000000000', 'Quantidade de pagamentos possíveis': '  ', 'Identificação da ocorrência': '01', 'CODIGO DO DOC': '419945    ', 'Data do vencimento': '030325', 'Valor': '0000000268022', 'Banco': '000', 'Agência depositária': '00000', 'Identificação': 'N', 'Data da emissão do título': '131224', 'Valor a ser cobrado por dia de atraso': '0000000000178', 'desconto ate': '000000', 'Valor do desconto': '0000000000000', 'Valor do IOF': '0000000000000', 'Valor do abatimento a ser concedido ou cancelado': '0000000000000', 'cnpj pagador': '22968133000199', 'Cliente': 'FARMACIA BRASIL LTDA                    ', 'endereco': 'AV URUGUAI 1499                         ', 'Número sequencial do registro': '000034'}
# {'Identificação do registro': '1', 'Identificação da empresa beneficiária no banco': '00010000181400665', 'Número de controle do participante': 'E419946                  ', 'Código do banco a ser debitado na câmara de compensação': '000', 'Campo de multa': '2', 'Percentual multa': '0500', 'Identificação do título no banco': '00000001548', 'Dígito de auto conferência do número bancário': '6', 'Desconto': '0000000000', 'Quantidade de pagamentos possíveis': '  ', 'Identificação da ocorrência': '01', 'CODIGO DO DOC': '419946    ', 'Data do vencimento': '040325', 'Valor': '0000000268022', 'Banco': '000', 'Agência depositária': '00000', 'Identificação': 'N', 'Data da emissão do título': '131224', 'Valor a ser cobrado por dia de atraso': '0000000000178', 'desconto ate': '000000', 'Valor do desconto': '0000000000000', 'Valor do IOF': '0000000000000', 'Valor do abatimento a ser concedido ou cancelado': '0000000000000', 'cnpj pagador': '22968133000199', 'Cliente': 'FARMACIA BRASIL LTDA                    ', 'endereco': 'AV URUGUAI 1499                         ', 'Número sequencial do registro': '000035'}
# {'Identificação do registro': '1', 'Identificação da empresa beneficiária no banco': '00010000181400665', 'Número de controle do participante': 'F419947                  ', 'Código do banco a ser debitado na câmara de compensação': '000', 'Campo de multa': '2', 'Percentual multa': '0500', 'Identificação do título no banco': '00000001549', 'Dígito de auto conferência do número bancário': '4', 'Desconto': '0000000000', 'Quantidade de pagamentos possíveis': '  ', 'Identificação da ocorrência': '01', 'CODIGO DO DOC': '419947    ', 'Data do vencimento': '070325', 'Valor': '0000000268022', 'Banco': '000', 'Agência depositária': '00000', 'Identificação': 'N', 'Data da emissão do título': '131224', 'Valor a ser cobrado por dia de atraso': '0000000000178', 'desconto ate': '000000', 'Valor do desconto': '0000000000000', 'Valor do IOF': '0000000000000', 'Valor do abatimento a ser concedido ou cancelado': '0000000000000', 'cnpj pagador': '22968133000199', 'Cliente': 'FARMACIA BRASIL LTDA                    ', 'endereco': 'AV URUGUAI 1499                         ', 'Número sequencial do registro': '000036'}
# {'Identificação do registro': '1', 'Identificação da empresa beneficiária no banco': '00010000181400665', 'Número de controle do participante': 'T419948                  ', 'Código do banco a ser debitado na câmara de compensação': '000', 'Campo de multa': '2', 'Percentual multa': '0500', 'Identificação do título no banco': '00000001550', 'Dígito de auto conferência do número bancário': '8', 'Desconto': '0000000000', 'Quantidade de pagamentos possíveis': '  ', 'Identificação da ocorrência': '01', 'CODIGO DO DOC': '419948    ', 'Data do vencimento': '100325', 'Valor': '0000000268022', 'Banco': '000', 'Agência depositária': '00000', 'Identificação': 'N', 'Data da emissão do título': '131224', 'Valor a ser cobrado por dia de atraso': '0000000000178', 'desconto ate': '000000', 'Valor do desconto': '0000000000000', 'Valor do IOF': '0000000000000', 'Valor do abatimento a ser concedido ou cancelado': '0000000000000', 'cnpj pagador': '22968133000199', 'Cliente': 'FARMACIA BRASIL LTDA                    ', 'endereco': 'AV URUGUAI 1499                         ', 'Número sequencial do registro': '000037'}
# {'Identificação do registro': '1', 'Identificação da empresa beneficiária no banco': '00010000181400665', 'Número de controle do participante': 'Q419949                  ', 'Código do banco a ser debitado na câmara de compensação': '000', 'Campo de multa': '2', 'Percentual multa': '0500', 'Identificação do título no banco': '00000001551', 'Dígito de auto conferência do número bancário': '6', 'Desconto': '0000000000', 'Quantidade de pagamentos possíveis': '  ', 'Identificação da ocorrência': '01', 'CODIGO DO DOC': '
 'desconto ate': '000000', 'Valor do desconto': '0000000000000', 'Valor do IOF': '0000000000000', 'Valor do abatimento a ser concedido ou cancelado': '0000000000000', 'cnpj pagador': '04865934000147', 'Cliente': 'SANTOS & COSTA DROGARIA LTDA            ', 'endereco': 'RUA DR EDGARDO PEREIRA VELHO 346        ', 'Número sequencial do registro': '000048'}
# {'Identificação do registro': '1', 'Identificação da empresa beneficiária no banco': '00010000181400665', 'Número de controle do participante': 'X419960                  ', 'Código do banco a ser debitado na câmara de compensação': '000', 'Campo de multa': '2', 'Percentual multa': '0500', 'Identificação do título no banco': '00000001562', 'Dígito de auto conferência do número bancário': '1', 'Desconto': '0000000000', 'Quantidade de pagamentos possíveis': '  ', 'Identificação da ocorrência': '01', 'CODIGO DO DOC': '419960    ', 'Data do vencimento': '210225', 'Valor': '0000000036400', 'Banco': '000', 'Agência depositária': '00000', 'Identificação': 'N', 'Data da emissão do título': '131224', 'Valor a ser cobrado por dia de atraso': '0000000000024', 'desconto ate': '000000', 'Valor do desconto': '0000000000000', 'Valor do IOF': '0000000000000', 'Valor do abatimento a ser concedido ou cancelado': '0000000000000', 'cnpj pagador': '04865934000147', 'Cliente': 'SANTOS & COSTA DROGARIA LTDA            ', 'endereco': 'RUA DR EDGARDO PEREIRA VELHO 346        ', 'Número sequencial do registro': '000049'}
# {'Identificação do registro': '9', 'Identificação da empresa beneficiária no banco': '                 ', 'Número de controle do participante': '                         ', 'Código do banco a ser debitado na câmara de compensação': '   ', 'Campo de multa': ' ', 'Percentual multa': '    ', 'Identificação do título no banco': '           ', 'Dígito de auto conferência do número bancário': ' ', 'Desconto': '          ', 'Quantidade de pagamentos possíveis': '  ', 'Identificação da ocorrência': '  ', 'CODIGO DO DOC': '          ', 'Data do vencimento': '      ', 'Valor': '             ', 'Banco': '   ', 'Agência depositária': '     ', 'Identificação': ' ', 'Data da emissão do título': '      ', 'Valor a ser cobrado por dia de atraso': '             ', 'desconto ate': '      ', 'Valor do desconto': '             ', 'Valor do IOF': '             ', 'Valor do abatimento a ser concedido ou cancelado': '             ', 'cnpj pagador': '              ', 'Cliente': '                                        ', 'endereco': '                                        ', 'Número sequencial do registro': '000050'}

# %%
nome_arquivo = os.path.basename(arquivo_cnab)
nome_arquivo
# Out:
# 'CB13120000001.REM'

# %%
#ler o corpo da Remessa
import pandas as pd
import os

# %%
dados = pd.DataFrame.from_dict(cabecario)

# %%
dados = dados.drop(dados.index[-1])

# %%
dados['Nome do arquivo'] = nome_arquivo
dados['Nome do arquivo'].fillna(method='ffill', inplace=True)

# %%
dados['CODIGO DO DOC'] = dados['CODIGO DO DOC'].str.strip()

dados['CODIGO DO DOC'] = dados['CODIGO DO DOC'].str.replace(' ', '')

# %%
dados['Identificação da ocorrência'] = dados['Identificação da ocorrência'].str.strip()

dados['Identificação da ocorrência'] = dados['Identificação da ocorrência'].str.replace(' ', '')

# %%
dados['Desconto'] =dados['Desconto'].str.lstrip('0')
dados['Desconto'] = dados['Desconto'].apply(lambda x: f'{str(x)[:-2]},{str(x)[-2:]}')
dados['Valor'] =dados['Valor'].str.lstrip('0')
dados['Valor'] = dados['Valor'].apply(lambda x: f'{str(x)[:-2]},{str(x)[-2:]}')
dados['Valor do desconto'] =dados['Valor do desconto'].str.lstrip('0')
dados['Valor do desconto'] = dados['Valor do desconto'].apply(lambda x: f'{str(x)[:-2]},{str(x)[-2:]}')

# %%
dados.loc[dados['Identificação da ocorrência'] == '01', 'Identificação da ocorrência'] = "Enviado"
dados.loc[dados['Identificação da ocorrência'] == '02', 'Identificação da ocorrência'] = "Pedido de baixa"
dados.loc[dados['Identificação da ocorrência'] == '04', 'Identificação da ocorrência'] = "CONCESSÃO DE ABATIMENTO"
dados.loc[dados['Identificação da ocorrência'] == '06', 'Identificação da ocorrência'] = "Alteração de vencimento"
dados.loc[dados['Identificação da ocorrência'] == '07', 'Identificação da ocorrência'] = "Atualização/Inclusão do Número de Controle do Participante"
dados.loc[dados['Identificação da ocorrência'] == '08', 'Identificação da ocorrência'] = "Atualização Número de Documento Seu Número)"
dados.loc[dados['Identificação da ocorrência'] == '09', 'Identificação da ocorrência'] = "Instrução para protesto"
dados.loc[dados['Identificação da ocorrência'] == '10', 'Identificação da ocorrência'] = "Atualização/Inclusão da Chave da NF"
dados.loc[dados['Identificação da ocorrência'] == '19', 'Identificação da ocorrência'] = "Desistência/Cancelamento de protesto"
dados.loc[dados['Identificação da ocorrência'] == '23', 'Identificação da ocorrência'] = "Instrução para Grafeno Titularidades"

# %%
dados['Data do vencimento'] = dados['Data do vencimento'].astype(str).str.zfill(6)
dados['Data do vencimento'] = dados['Data do vencimento'].apply(lambda x: f"{x[:2]}/{x[2:4]}/{x[4:]}")
dados['Data da emissão do título'] = dados['Data da emissão do título'].astype(str).str.zfill(6)
dados['Data da emissão do título'] = dados['Data da emissão do título'].apply(lambda x: f"{x[:2]}/{x[2:4]}/{x[4:]}")
dados['desconto ate'] = dados['desconto ate'].astype(str).str.zfill(6)
dados['desconto ate'] = dados['desconto ate'].apply(lambda x: f"{x[:2]}/{x[2:4]}/{x[4:]}")

# %%
df_dados = dados

# %% [markdown]
# # Cabeçalho

# %%
# Filtrar apenas os arquivos que têm a extensão .REM
arquivos_rem = [arquivo for arquivo in arquivos if arquivo.endswith('.REM')]

# Encontre o arquivo REM mais recente com base na data de modificação
if arquivos_rem:
    caminho_arquivo_rem = max(arquivos_rem, key=lambda arquivo: os.path.getmtime(os.path.join(pasta, arquivo)))
    
    # Crie o caminho completo para o arquivo REM mais recente
    cnab = os.path.join(pasta, caminho_arquivo_rem)

# Defina o caminho para o arquivo CNAB do Santander
arquivo_cnab =  cnab

# Crie uma lista para armazenar os registros lidos
cabecario = []

with open(arquivo_cnab, 'r') as arquivo:
    # Leia cada linha do arquivo
    linhas = arquivo.readlines()

    for linha in linhas[0:1]:    # Faça algo com cada linha do arquivo, por exemplo, imprima-a
        campo1 = linha[0:1]
        campo2 = linha[1:2]
        campo3 = linha[2:9]        
        campo4 = linha[9:11]    
        campo5 = linha[46:76]   
        campo6 = linha[76:79] 
        campo7 = linha[79:94] 
        campo8 = linha[94:100]  
        campo9 = linha[108:110] 
        campo10 = linha[110:117] 
        campo11 = linha[394:400]            


        registro = {
            'TIPO DE REGISTRO HEADER cabeçalho': campo1,
            'Identificação do arquivo remessa cabeçalho': campo2,
            'Literal remessa cabeçalho': campo3,
             'Código do serviço cabeçalho': campo4,
              'Nome da empresa cabeçalho': campo5,
             'Número do Banco cabeçalho': campo6,
             'Nome do banco cabeçalho': campo7,
             'Data de gravação do arquivo cabeçalho': campo8,      
             'Identificação do sistema cabeçalho': campo9,     
             'Número sequencial de remessa cabeçalho': campo10,            
             'Número sequencial do registro cabeçalho': campo11,        

 }
        
        cabecario.append(registro)

for registro in cabecario:
    print(registro)
# Out:
# {'TIPO DE REGISTRO HEADER cabeçalho': '0', 'Identificação do arquivo remessa cabeçalho': '1', 'Literal remessa cabeçalho': 'REMESSA', 'Código do serviço cabeçalho': '01', 'Nome da empresa cabeçalho': 'GRAFENO PAGAMENTOS            ', 'Número do Banco cabeçalho': '274', 'Nome do banco cabeçalho': 'MONEYPLUS      ', 'Data de gravação do arquivo cabeçalho': '131224', 'Identificação do sistema cabeçalho': 'MX', 'Número sequencial de remessa cabeçalho': '0000037', 'Número sequencial do registro cabeçalho': '000001'}

# %%
df_cabecario = pd.DataFrame.from_dict(cabecario)

# %%
df_resultado = pd.concat([df_dados, df_cabecario], axis=1)

# %%
df_resultado.replace('None', pd.NA, inplace=True)

# Preencher os valores nulos na coluna 'Código de Serviço' com os valores da linha anterior
df_resultado['TIPO DE REGISTRO HEADER cabeçalho'].fillna(method='ffill', inplace=True)
df_resultado['Identificação do arquivo remessa cabeçalho'].fillna(method='ffill', inplace=True)
df_resultado['Literal remessa cabeçalho'].fillna(method='ffill', inplace=True)
df_resultado['Código do serviço cabeçalho'].fillna(method='ffill', inplace=True)
df_resultado['Nome da empresa cabeçalho'].fillna(method='ffill', inplace=True)
df_resultado['Número do Banco cabeçalho'].fillna(method='ffill', inplace=True)
df_resultado['Nome do banco cabeçalho'].fillna(method='ffill', inplace=True)
df_resultado['Data de gravação do arquivo cabeçalho'].fillna(method='ffill', inplace=True)
df_resultado['Identificação do sistema cabeçalho'].fillna(method='ffill', inplace=True)
df_resultado['Número sequencial de remessa cabeçalho'].fillna(method='ffill', inplace=True)
df_resultado['Número sequencial do registro cabeçalho'].fillna(method='ffill', inplace=True)

# %%
df_resultado = df_resultado.replace({pd.NA: None, pd.NaT: None})

# %% [markdown]
# # Trailler

# %%
# Filtrar apenas os arquivos que têm a extensão .REM
arquivos_rem = [arquivo for arquivo in arquivos if arquivo.endswith('.REM')]

# Encontre o arquivo REM mais recente com base na data de modificação
if arquivos_rem:
    caminho_arquivo_rem = max(arquivos_rem, key=lambda arquivo: os.path.getmtime(os.path.join(pasta, arquivo)))
    
    # Crie o caminho completo para o arquivo REM mais recente
    cnab = os.path.join(pasta, caminho_arquivo_rem)

# Defina o caminho para o arquivo CNAB do Santander
arquivo_cnab =  cnab

# Crie uma lista para armazenar os registros lidos
cabecario = []

with open(arquivo_cnab, 'r') as arquivo:
    # Leia cada linha do arquivo
    linhas = arquivo.readlines()

    for linha in linhas[-1:]:    # Faça algo com cada linha do arquivo, por exemplo, imprima-a
        campo1 = linha[0:1]
        campo2 = linha[394:400]

        


        registro = {
            'Identificação do registro trailer': campo1,
             'Número sequencial de registro trailer': campo2,
            

            
            
            
            

 }
        
        cabecario.append(registro)

for registro in cabecario:
    print(registro)
# Out:
# {'Identificação do registro trailer': '9', 'Número sequencial de registro trailer': '000050'}

# %%
trailer = pd.DataFrame.from_dict(cabecario)
df_resultado = pd.concat([df_resultado, trailer], axis=1)
df_resultado = df_resultado.replace({pd.NA: None, pd.NaT: None})

# %%
df_resultado['Identificação do registro trailer'].fillna(method='ffill', inplace=True)
df_resultado['Número sequencial de registro trailer'].fillna(method='ffill', inplace=True)
df_resultado = df_resultado.reset_index()

# %%
df_resultado['Data de gravação do arquivo cabeçalho']= pd.to_datetime(df_resultado['Data de gravação do arquivo cabeçalho'])
df_resultado['Data de gravação do arquivo cabeçalho'] = df_resultado['Data de gravação do arquivo cabeçalho'].dt.strftime('%Y-%d-%m')
# Out:
# C:\Users\elean\AppData\Local\Temp\ipykernel_16776\4230455518.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_resultado['Data de gravação do arquivo cabeçalho']= pd.to_datetime(df_resultado['Data de gravação do arquivo cabeçalho'])

# %%
df_resultado = df_resultado.drop(columns=['index'])

# %%
df_resultado['Data de gravação do arquivo cabeçalho']
# Out:
# 0    2024-12-13
# 1    2024-12-13
# 2    2024-12-13
# 3    2024-12-13
# 4    2024-12-13
# 5    2024-12-13
# 6    2024-12-13
# 7    2024-12-13
# 8    2024-12-13
# 9    2024-12-13
# 10   2024-12-13
# 11   2024-12-13
# 12   2024-12-13
# 13   2024-12-13
# 14   2024-12-13
# 15   2024-12-13
# 16   2024-12-13
# 17   2024-12-13
# 18   2024-12-13
# 19   2024-12-13
# 20   2024-12-13
# 21   2024-12-13
# 22   2024-12-13
# 23   2024-12-13
# 24   2024-12-13
# 25   2024-12-13
# 26   2024-12-13
# 27   2024-12-13
# 28   2024-12-13
# 29   2024-12-13
# 30   2024-12-13
# 31   2024-12-13
# 32   2024-12-13
# 33   2024-12-13
# 34   2024-12-13
# 35   2024-12-13
# 36   2024-12-13
# 37   2024-12-13
# 38   2024-12-13
# 39   2024-12-13
# 40   2024-12-13
# 41   2024-12-13
# 42   2024-12-13
# 43   2024-12-13
# 44   2024-12-13
# 45   2024-12-13
# 46   2024-12-13
# 47   2024-12-13
# Name: Data de gravação do arquivo cabeçalho, dtype: datetime64[ns]

# %%
df_resultado['Data de gravação do arquivo cabeçalho'] = pd.to_datetime(df_resultado['Data de gravação do arquivo cabeçalho'], format='%Y-%d-%m')

# Trocando o dia pelo mês
# df_resultado['Data de gravação do arquivo cabeçalho'] = df_resultado['Data de gravação do arquivo cabeçalho'].apply(lambda x: pd.Timestamp(year=x.year, month=x.day, day=x.month))

# %%
df_resultado['Data de gravação do arquivo cabeçalho'] =df_resultado['Data de gravação do arquivo cabeçalho'].astype(str)

# %%
df_resultado
# Out:
#    Identificação do registro Identificação da empresa beneficiária no banco  \
# 0                          1                              00010000181400665
# 1                          1                              00010000181400665
# 2                          1                              00010000181400665
# 3                          1                              00010000181400665
# 4                          1                              00010000181400665
# 5                          1                              00010000181400665
# 6                          1                              00010000181400665
# 7                          1                              00010000181400665
# 8                          1                              00010000181400665
# 9                          1                              00010000181400665
# 10                         1                              00010000181400665
# 11                         1                              00010000181400665
# 12                         1                              00010000181400665
# 13                         1                              00010000181400665
# 14                         1                              00010000181400665
# 15                         1                              00010000181400665
# 16                         1                              00010000181400665
# 17                         1                              00010000181400665
# 18                         1                              00010000181400665
# 19                         1                              00010000181400665
# 20                         1                              00010000181400665
# 21                         1                              00010000181400665
# 22                         1                              00010000181400665
# 23                         1                              00010000181400665
# 24                         1                              00010000181400665
# 25                         1                              00010000181400665
# 26                         1                              00010000181400665
# 27                         1                              00010000181400665
# 28                         1                              00010000181400665
# 29                         1                              00010000181400665
# 30                         1                              00010000181400665
# 31                         1                              00010000181400665
# 32                         1                              00010000181400665
# 33                         1                              00010000181400665
# 34                         1                              00010000181400665
# 35                         1                              00010000181400665
# 36                         1                              00010000181400665
# 37                         1                              00010000181400665
# 38                         1                              00010000181400665
# 39                         1                              00010000181400665
# 40                         1                              00010000181400665
# 41                         1                              00010000181400665
# 42                         1                              00010000181400665
# 43                         1                              00010000181400665
# 44                         1                              00010000181400665
# 45                         1                              00010000181400665
# 46                         1                              00010000181400665
# 47                         1                              00010000181400665
#
#    Número de controle do participante  \
# 0           E418719
# 1           K418720
# 2           J418721
# 3           W418900
# 4           D418901
# 5           O419918
# 6           Z419919
# 7           W419920
# 8           J419921
# 9           O419922
# 10          U419923
# 11          Y419924
# 12          R419925
# 13          A419926
# 14          A419927
# 15          F419928
# 16          S419929
# 17          G419930
# 18          C419931
# 19          J419932
# 20          W419933
# 21          L419934
# 22          F419935
# 23          U419936
# 24          T419937
# 25          T419938
# 26          U419939
# 27          P419940
# 28          C419941
# 29          V419942
# 30          V419943
# 31          M419944
# 32          Z419945
# 33          E419946
# 34          F419947
# 35          T419948
# 36          Q419949
# 37          N419950
# 38          H419951
# 39          J419952
# 40          N419953
# 41          C419954
# 42          M419955
# 43          C419956
# 44          R419957
# 45          Z419958
# 46          I419959
# 47          X419960
#
#    Código do banco a ser debitado na câmara de compensação Campo de multa  \
# 0                                                 000                   0
# 1                                                 000                   0
# 2                                                 000                   0
# 3                                                 000                   2
# 4                                                 000                   2
# 5                                                 000                   2
# 6                                                 000                   2
# 7                                                 000                   2
# 8                                                 000                   2
# 9                                                 000                   2
# 10                                                000                   2
# 11                                                000                   2
# 12                                                000                   2
# 13                                                000                   2
# 14                                                000                   2
# 15                                                000                   2
# 16                                                000                   2
# 17                                                000                   2
# 18                                                000                   2
# 19                                                000                   2
# 20                                                000                   2
# 21                                                000                   2
# 22                                                000                   2
# 23                                                000                   2
# 24                                                000                   2
# 25                                                000                   2
# 26                                                000                   2
# 27                                                000                   2
# 28                                                000                   2
# 29                                                000                   2
# 30                                                000                   2
# 31                                                000                   2
# 32                                                000                   2
# 33                                                000                   2
# 34                                                000                   2
# 35                                                000                   2
# 36                                                000                   2
# 37                                                000                   2
# 38                                                000                   2
# 39                                                000                   2
# 40                                                000                   2
# 41                                                000                   2
# 42                                                000                   2
# 43                                                000                   2
# 44                                                000                   2
# 45                                                000                   2
# 46                                                000                   2
# 47                                                000                   2
#
#    Percentual multa Identificação do título no banco  \
# 0              0000                      00000000321
# 1              0000                      00000000322
# 2              0000                      00000000323
# 3              0500                      00000000502
# 4              0500                      00000000503
# 5              0500                      00000001520
# 6              0500                      00000001521
# 7              0500                      00000001522
# 8              0500                      00000001523
# 9              0500                      00000001524
# 10             0500                      00000001525
# 11             0500                      00000001526
# 12             0500                      00000001527
# 13             0500                      00000001528
# 14             0500                      00000001529
# 15             0500                      00000001530
# 16             0500                      00000001531
# 17             0500                      00000001532
# 18             0500                      00000001533
# 19             0500                      00000001534
# 20             0500                      00000001535
# 21             0500                      00000001536
# 22             0500                      00000001537
# 23             0500                      00000001538
# 24             0500                      00000001539
# 25             0500                      00000001540
# 26             0500                      00000001541
# 27             0500                      00000001542
# 28             0500                      00000001543
# 29             0500                      00000001544
# 30             0500                      00000001545
# 31             0500                      00000001546
# 32             0500                      00000001547
# 33             0500                      00000001548
# 34             0500                      00000001549
# 35             0500                      00000001550
# 36             0500                      00000001551
# 37             0500                      00000001552
# 38             0500                      00000001553
# 39             0500                      00000001554
# 40             0500                      00000001555
# 41             0500                      00000001556
# 42             0500                      00000001557
# 43             0500                      00000001558
# 44             0500                      00000001559
# 45             0500                      00000001560
# 46             0500                      00000001561
# 47             0500                      00000001562
#
#    Dígito de auto conferência do número bancário Desconto  \
# 0                                              6        ,
# 1                                              4        ,
# 2                                              2        ,
# 3                                              2        ,
# 4                                              0        ,
# 5                                              6        ,
# 6                                              4        ,
# 7                                              2        ,
# 8                                              0        ,
# 9                                              9        ,
# 10                                             7        ,
# 11                                             5        ,
# 12                                             3        ,
# 13                                             1        ,
# 14                                             P        ,
# 15                                             3        ,
# 16                                             1        ,
# 17                                             P        ,
# 18                                             8        ,
# 19                                             6        ,
# 20                                             4        ,
# 21                                             2        ,
# 22                                             0        ,
# 23                                             9        ,
# 24                                             7        ,
# 25                                             0        ,
# 26                                             9        ,
# 27                                             7        ,
# 28                                             5        ,
# 29                                             3        ,
# 30                                             1        ,
# 31                                             P        ,
# 32                                             8        ,
# 33                                             6        ,
# 34                                             4        ,
# 35                                             8        ,
# 36                                             6        ,
# 37                                             4        ,
# 38                                             2        ,
# 39                                             0        ,
# 40                                             9        ,
# 41                                             7        ,
# 42                                             5        ,
# 43                                             3        ,
# 44                                             1        ,
# 45                                             5        ,
# 46                                             3        ,
# 47                                             1        ,
#
#    Quantidade de pagamentos possíveis  ... Código do serviço cabeçalho  \
# 0                                      ...                          01
# 1                                      ...                          01
# 2                                      ...                          01
# 3                                      ...                          01
# 4                                      ...                          01
# 5                                      ...                          01
# 6                                      ...                          01
# 7                                      ...                          01
# 8                                      ...                          01
# 9                                      ...                          01
# 10                                     ...                          01
# 11                                     ...                          01
# 12                                     ...                          01
# 13                                     ...                          01
# 14                                     ...                          01
# 15                                     ...                          01
# 16                                     ...                          01
# 17                                     ...                          01
# 18                                     ...                          01
# 19                                     ...                          01
# 20                                     ...                          01
# 21                                     ...                          01
# 22                                     ...                          01
# 23                                     ...                          01
# 24                                     ...                          01
# 25                                     ...                          01
# 26                                     ...                          01
# 27                                     ...                          01
# 28                                     ...                          01
# 29                                     ...                          01
# 30                                     ...                          01
# 31                                     ...                          01
# 32                                     ...                          01
# 33                                     ...                          01
# 34                                     ...                          01
# 35                                     ...                          01
# 36                                     ...                          01
# 37                                     ...                          01
# 38                                     ...                          01
# 39                                     ...                          01
# 40                                     ...                          01
# 41                                     ...                          01
# 42                                     ...                          01
# 43                                     ...                          01
# 44                                     ...                          01
# 45                                     ...                          01
# 46                                     ...                          01
# 47                                     ...                          01
#
#          Nome da empresa cabeçalho Número do Banco cabeçalho  \
# 0   GRAFENO PAGAMENTOS                                   274
# 12                                  000001                                 9
# 13                                  000001                                 9
# 14                                  000001                                 9
# 15                                  000001                                 9
# 16                                  000001                                 9
# 17                                  000001                                 9
# 18                                  000001                                 9
# 19                                  000001                                 9
# 20                                  000001                                 9
# 21                                  000001                                 9
# 22                                  000001                                 9
# 23                                  000001                                 9
# 24                                  000001                                 9
# 25                                  000001                                 9
# 26                                  000001                                 9
# 27                                  000001                                 9
# 28                                  000001                                 9
# 29                                  000001                                 9
# 30                                  000001                                 9
# 31                                  000001                                 9
# 32                                  000001                                 9
# 33                                  000001                                 9
# 34                                  000001                                 9
# 35                                  000001                                 9
# 36                                  000001                                 9
# 37                                  000001                                 9
# 38                                  000001                                 9
# 39                                  000001                                 9
# 40                                  000001                                 9
# 41                                  000001                                 9
# 42                                  000001                                 9
# 43                                  000001                                 9
# 44                                  000001                                 9
# 45                                  000001                                 9
# 46                                  000001                                 9
# 47                                  000001                                 9
#
#    Número sequencial de registro trailer
# 0                                 000050
# 1                                 000050
# 2                                 000050
# 3                                 000050
# 4                                 000050
# 5                                 000050
# 6                                 000050
# 7                                 000050
# 8                                 000050
# 9                                 000050
# 10                                000050
# 11                                000050
# 12                                000050
# 13                                000050
# 14                                000050
# 15                                000050
# 16                                000050
# 17                                000050
# 18                                000050
# 19                                000050
# 20                                000050
# 21                                000050
# 22                                000050
# 23                                000050
# 24                                000050
# 25                                000050
# 26                                000050
# 27                                000050
# 28                                000050
# 29                                000050
# 30                                000050
# 31                                000050
# 32                                000050
# 33                                000050
# 34                                000050
# 35                                000050
# 36                                000050
# 37                                000050
# 38                                000050
# 39                                000050
# 40                                000050
# 41                                000050
# 42                                000050
# 43                                000050
# 44                                000050
# 45                                000050
# 46                                000050
# 47                                000050
#
# [48 rows x 41 columns]

# %%
# df_resultado.to_excel(r'C:\Users\elean\Desktop\bancodedados\testegarfeno.xlsx')

# %%
import mysql.connector
import pandas as pd

# Seus dados de conexão
mydb = mysql.connector.connect(
    host='db_sabertrimed.mysql.dbaas.com.br',
    user='db_sabertrimed',
    password='s@BRtR1m3d',
    database='db_sabertrimed',
)


# Função para inserir dados na tabela
def inserir_dados(cursor, tabela, df_resultado):
    for index, row in df_resultado.iterrows():
        placeholders = ', '.join(['%s'] * len(row))
        columns = ', '.join(f"`{col}`" for col in row.keys())
        sql = f"INSERT INTO {tabela} ({columns}) VALUES ({placeholders})"
        cursor.execute(sql, tuple(row))

# Cria um cursor para executar consultas
cursor = mydb.cursor()

# Nome da tabela no banco de dados
nome_tabela = 'remessa_grafeno'

# Insere os dados na tabela
inserir_dados(cursor, nome_tabela, df_resultado)

# Commit para salvar as alterações
mydb.commit()

# Fecha o cursor e a conexão
cursor.close()
mydb.close()

print("remessa salva no banco de dados!")
# Out:
# remessa salva no banco de dados!

# %%
import shutil
# Pasta de destino
pasta_destino = 'C:/Users/elean/Desktop/BANCOS/grafeno/lido/'

# Movendo o arquivo
shutil.move(arquivo_cnab, pasta_destino)
print(f'O arquivo foi movido para {pasta_destino}')
# Out:
# O arquivo foi movido para C:/Users/elean/Desktop/BANCOS/grafeno/lido/
