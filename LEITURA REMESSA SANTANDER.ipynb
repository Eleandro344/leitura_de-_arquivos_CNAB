# %%
#ler o corpo da Remessa

import os
pasta =  'C:/Users/elean/Desktop/BANCOS/santander'


# Liste todos os arquivos na pasta
arquivos = os.listdir(pasta)

# Filtrar apenas os arquivos que têm a extensão .REM
arquivos_rem = [arquivo for arquivo in arquivos if arquivo.endswith('.REM')]

# Encontre o arquivo REM mais recente com base na data de modificação
if arquivos_rem:
    caminho_arquivo_rem = max(arquivos_rem, key=lambda arquivo: os.path.getmtime(os.path.join(pasta, arquivo)))
    
    # Crie o caminho completo para o arquivo REM mais recente
    cnab = os.path.join(pasta, caminho_arquivo_rem)

# Defina o caminho para o arquivo CNAB do Santander
arquivo_cnab =  cnab

# Crie uma lista para armazenar os registros lidos
cabecario = []

with open(arquivo_cnab, 'r') as arquivo:
    # Leia cada linha do arquivo
    linhas = arquivo.readlines()

    for linha in linhas[1:]:    # Faça algo com cada linha do arquivo, por exemplo, imprima-a
        campo1 = linha[0:1]
        campo2 = linha[1:3]
        campo3 = linha[3:17]
        campo4 = linha[17:21]    
        campo5 = linha[21:29]        
        campo6 = linha[29:37]        
        campo7 = linha[37:62]        
        campo8 = linha[62:70]        
        campo9 = linha[70:76]        
        campo10 = linha[76:77]        
        campo11 = linha[77:78]  
        campo12 = linha[78:82]        
        campo13 = linha[82:84]        
        campo14 = linha[84:97]        
        campo15 = linha[101:107]        
        campo16 = linha[107:108]        
        campo17 = linha[108:110]        
        campo18 = linha[110:120]        
        campo19 = linha[120:126]        
        campo20 = linha[126:139]        
        campo21 = linha[139:142]        
        campo22 = linha[142:147]   
        campo23 = linha[147:149]        
        campo24 = linha[149:150]        
        campo25 = linha[150:156]        
        campo26 = linha[156:158]        
        campo27 = linha[158:160]        
        campo28 = linha[160:173]        
        campo29 = linha[173:179]        
        campo30 = linha[179:192]        
        campo31 = linha[192:205]        
        campo32 = linha[205:218]        
        campo33 = linha[218:220]        
        campo34 = linha[220:234]        
        campo35 = linha[234:274]        
        campo36 = linha[274:314]        
        campo37 = linha[314:326]        
        campo38 = linha[326:331]        
        campo39 = linha[331:334]        
        campo40 = linha[334:349]        
        campo41 = linha[349:351]  
        campo42 = linha[382:383]        
        campo43 = linha[383:385]        
        campo44 = linha[391:393]        
        campo45 = linha[394:400]        
        #campo41 = linha[349:351]        
        #campo41 = linha[349:351]        
        #campo41 = linha[349:351]        
        #campo41 = linha[349:351]        
        #campo41 = linha[349:351]        
        #campo41 = linha[349:351]        
        #campo41 = linha[349:351]        
        

        
        
        
        

        #campo32= linha[218:220]
        #campo32= linha[218:220]
        registro = {
            'Código do Registro': campo1,
            'Tipo de inscrição do beneficiário': campo2,   
            'Nº de inscrição do beneficiário': campo3,     
            'Código da agência beneficiário': campo4,     
            'Conta movimento beneficiário': campo5,   
            'Conta cobrança beneficiário': campo6,             
            'Identificação do boleto na empresa': campo7,             
            'Identificação do boleto no banco': campo8,             
            'Data do desconto 2': campo9,             
            'Reservado (uso banco)': campo10,             
            'Código de Multa': campo11,             
            'Percentual de Multa': campo12,             
            'Código da Moeda': campo13,             
            'Valor do boleto em outra unidade': campo14,             
            'Data da Multa': campo15,             
            'Tipo de Cobrança': campo16,             
            'Código de movimento remessa': campo17,             
            'CODIGO DO DOC': campo18,             
            'Data de vencimento do boleto': campo19,             
            'Valor nominal do boleto': campo20,            
            'Número do banco cobrador': campo21,             
            'Código agência Cobradora': campo22,             
            'Espécie do boleto': campo23,             
            'Identificação boleto aceite / não aceite': campo24,             
            'Data de emissão do boleto': campo25,             
            'Primeira instrução': campo26,             
            'Segunda instrução': campo27,             
            'Valor de Mora dia': campo28,             
            'Data Limite para concessão do desconto': campo29,             
            'Valor do desconto a ser concedido': campo30,             
            'Percentual do IOF a ser recolhido': campo31,   
            'Valor do abatimento ou Valor do segundo desconto': campo32,             
            'Tipo de inscrição do Pagador': campo33,             
            'Número de inscrição do Pagador': campo34,             
            'Nome do Pagador': campo35,             
            'Endereço do Pagador': campo36,             
            'Bairro do Pagador': campo37,             
            'Cep do Pagador': campo38,             
            'Sufixo do Cep do Pagador': campo39,             
            'Cidade do Pagador': campo40,             
            'Unidade de Federação do Pagador': campo41,   
            'Identificador do complemento': campo42,             
            'Complemento': campo43,             
            'Número de dias corridos para Protesto': campo44,             
            'Número sequencial do registro no arquivo': campo45,             
            #'Unidade de Federação do Pagador': campo41,             
            #'Unidade de Federação do Pagador': campo41,             
            #'Unidade de Federação do Pagador': campo41,             
            #'Unidade de Federação do Pagador': campo41,             
            #'Unidade de Federação do Pagador': campo41,             
            #'Unidade de Federação do Pagador': campo41,             
            #'Unidade de Federação do Pagador': campo41,             
            #'Unidade de Federação do Pagador': campo41,             
            
            

            
            
            
 }
        
        cabecario.append(registro)

for registro in cabecario:
    print(registro)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 21
#      18     cnab = os.path.join(pasta, caminho_arquivo_rem)
#      20 # Defina o caminho para o arquivo CNAB do Santander
# ---> 21 arquivo_cnab =  cnab
#      23 # Crie uma lista para armazenar os registros lidos
#      24 cabecario = []
#
# NameError: name 'cnab' is not defined

# %%
arquivo_cnab

# %%
import pandas as pd
from datetime import datetime
data = pd.DataFrame.from_dict(cabecario)
data=data.reset_index()
dados = data.drop(data.index[-1])

# %%
data

# %%
dados

# %%
dados.loc[dados['Código de movimento remessa'] == '01', 'Código de movimento remessa'] = "Enviado"
dados.loc[dados['Código de movimento remessa'] == '02', 'Código de movimento remessa'] = "Solicitação de baixa"
dados.loc[dados['Código de movimento remessa'] == '04', 'Código de movimento remessa'] = "Concessão de abatimento"
dados.loc[dados['Código de movimento remessa'] == '05', 'Código de movimento remessa'] = "Cancelamento do abatimento"
dados.loc[dados['Código de movimento remessa'] == '06', 'Código de movimento remessa'] = "Alteração do vencimento"
dados.loc[dados['Código de movimento remessa'] == '07', 'Código de movimento remessa'] = " Alteração do número controle beneficiário"
dados.loc[dados['Código de movimento remessa'] == '08', 'Código de movimento remessa'] = "Alteração do Seu Número"
dados.loc[dados['Código de movimento remessa'] == '09', 'Código de movimento remessa'] = "Protestar"
dados.loc[dados['Código de movimento remessa'] == '15', 'Código de movimento remessa'] = "Transferência da carteira Simples para Cessão"
dados.loc[dados['Código de movimento remessa'] == '16', 'Código de movimento remessa'] = "Baixa de Cessão por Descaracterização"
dados.loc[dados['Código de movimento remessa'] == '17', 'Código de movimento remessa'] = "Baixa de Cessão por Pagamento*"
dados.loc[dados['Código de movimento remessa'] == '18', 'Código de movimento remessa'] = "Sustar o protesto (Após início do ciclo de protesto)"
dados.loc[dados['Código de movimento remessa'] == '47', 'Código de movimento remessa'] = "Alteração do valor nominal do boleto"
dados.loc[dados['Código de movimento remessa'] == '48', 'Código de movimento remessa'] = "Alteração do valor mínimo/percentual"
dados.loc[dados['Código de movimento remessa'] == '49', 'Código de movimento remessa'] = "Alteração do valor máximo/percentual"
dados.loc[dados['Espécie do boleto'] == '01', 'Espécie do boleto'] = "DM Duplicata Mercantil"

# %%
dados['CODIGO DO DOC'] = dados['CODIGO DO DOC'].str.strip()
dados['CODIGO DO DOC'] = dados['CODIGO DO DOC'].str.lstrip('0')

dados['Valor nominal do boleto'] = dados['Valor nominal do boleto'].str.lstrip('0')
dados['Valor de Mora dia'] = dados['Valor de Mora dia'].str.lstrip('0')
dados['Valor do desconto a ser concedido'] = dados['Valor do desconto a ser concedido'].str.strip()
dados['Percentual do IOF a ser recolhido'] = dados['Percentual do IOF a ser recolhido'].str.strip()
dados['Valor do abatimento ou Valor do segundo desconto'] = dados['Valor do abatimento ou Valor do segundo desconto'].str.strip()
dados['Valor do desconto a ser concedido'] = dados['Valor do desconto a ser concedido'].str.lstrip('0')

dados['Valor nominal do boleto'] = dados['Valor nominal do boleto'].apply(lambda x: f'{str(x)[:-2]},{str(x)[-2:]}')
dados['Valor de Mora dia'] = dados['Valor de Mora dia'].apply(lambda x: f'{str(x)[:-2]},{str(x)[-2:]}')
dados['Valor do desconto a ser concedido'] = dados['Valor do desconto a ser concedido'].apply(lambda x: f'{str(x)[:-2]},{str(x)[-2:]}')
dados['Valor do abatimento ou Valor do segundo desconto'] = dados['Valor do abatimento ou Valor do segundo desconto'].apply(lambda x: f'{str(x)[:-2]},{str(x)[-2:]}')

# %%
dados['Data do desconto 2'] = dados['Data do desconto 2'].astype(str).str.zfill(6)
dados['Data do desconto 2'] = dados['Data do desconto 2'].apply(lambda x: f"{x[:2]}/{x[2:4]}/{x[4:]}")
dados['Data da Multa'] = dados['Data da Multa'].astype(str).str.zfill(6)
dados['Data da Multa'] = dados['Data da Multa'].apply(lambda x: f"{x[:2]}/{x[2:4]}/{x[4:]}")
dados['Data de vencimento do boleto'] = dados['Data de vencimento do boleto'].astype(str).str.zfill(6)
dados['Data de vencimento do boleto'] = dados['Data de vencimento do boleto'].apply(lambda x: f"{x[:2]}/{x[2:4]}/{x[4:]}")
dados['Data de emissão do boleto'] = dados['Data de emissão do boleto'].astype(str).str.zfill(6)
dados['Data de emissão do boleto'] = dados['Data de emissão do boleto'].apply(lambda x: f"{x[:2]}/{x[2:4]}/{x[4:]}")
dados['Data Limite para concessão do desconto'] = dados['Data Limite para concessão do desconto'] .astype(str).str.zfill(6)
dados['Data Limite para concessão do desconto']  = dados['Data Limite para concessão do desconto'] .apply(lambda x: f"{x[:2]}/{x[2:4]}/{x[4:]}")

# %%
df_dados = dados

# %% [markdown]
# # CABEÇARIO

# %%
# Filtrar apenas os arquivos que têm a extensão .REM
arquivos_rem = [arquivo for arquivo in arquivos if arquivo.endswith('.REM')]

# Encontre o arquivo REM mais recente com base na data de modificação
if arquivos_rem:
    caminho_arquivo_rem = max(arquivos_rem, key=lambda arquivo: os.path.getmtime(os.path.join(pasta, arquivo)))
    
    # Crie o caminho completo para o arquivo REM mais recente
    cnab = os.path.join(pasta, caminho_arquivo_rem)

# Defina o caminho para o arquivo CNAB do Santander
arquivo_cnab =  cnab

# Crie uma lista para armazenar os registros lidos
cabecario = []

with open(arquivo_cnab, 'r') as arquivo:
    # Leia cada linha do arquivo
    linhas = arquivo.readlines()

    for linha in linhas[0:1]:    # Faça algo com cada linha do arquivo, por exemplo, imprima-a
        campo1 = linha[0:1]
        campo2 = linha[1:2]
        campo3 = linha[2:9]        
        campo4 = linha[9:11]    
        campo5 = linha[11:26]   
        campo6 = linha[26:46] 
        campo7 = linha[46:76] 
        campo8 = linha[76:79] 
        campo9 = linha[79:94] 
        campo10 = linha[94:100] 
        campo11 = linha[391:394]           
        campo12 = linha[394:400] 

        registro = {
            'Código do Registro header': campo1,
            'Código da Remessa': campo2,
            'Literal Remessa': campo3,
            'Código de Serviço': campo4,
             'Literal Serviço': campo5,
            'Código de Transmissão': campo6,
            'Nome da Empresa BENEFICIÁRIO': campo7,
            'Código do Banco': campo8,      
            'Nome do Banco': campo9,     
            'Data da Gravação do Arquivo': campo10,            
            'Nº Sequencial do Arquivo': campo11,        
            'Nº Sequencial do Registro': campo12,  
 }
        
        cabecario.append(registro)

for registro in cabecario:
    print(registro)

# %%
df_cabecario = pd.DataFrame.from_dict(cabecario)

# %%
df_resultado = pd.concat([df_dados, df_cabecario], axis=1)

# %%
df_resultado.replace('None', pd.NA, inplace=True)

# Preencher os valores nulos na coluna 'Código de Serviço' com os valores da linha anterior
df_resultado['Código do Registro header'].fillna(method='ffill', inplace=True)
df_resultado['Código da Remessa'].fillna(method='ffill', inplace=True)
df_resultado['Literal Remessa'].fillna(method='ffill', inplace=True)
df_resultado['Código de Serviço'].fillna(method='ffill', inplace=True)
df_resultado['Literal Serviço'].fillna(method='ffill', inplace=True)
df_resultado['Código de Transmissão'].fillna(method='ffill', inplace=True)
df_resultado['Nome da Empresa BENEFICIÁRIO'].fillna(method='ffill', inplace=True)
df_resultado['Código do Banco'].fillna(method='ffill', inplace=True)
df_resultado['Nome do Banco'].fillna(method='ffill', inplace=True)
df_resultado['Data da Gravação do Arquivo'].fillna(method='ffill', inplace=True)
df_resultado['Nº Sequencial do Arquivo'].fillna(method='ffill', inplace=True)
df_resultado['Nº Sequencial do Registro'].fillna(method='ffill', inplace=True)

# %%
df_resultado

# %%
df_resultado = df_resultado.replace({pd.NA: None, pd.NaT: None})

# %% [markdown]
# # Trailler

# %%
# Filtrar apenas os arquivos que têm a extensão .REM
arquivos_rem = [arquivo for arquivo in arquivos if arquivo.endswith('.REM')]

# Encontre o arquivo REM mais recente com base na data de modificação
if arquivos_rem:
    caminho_arquivo_rem = max(arquivos_rem, key=lambda arquivo: os.path.getmtime(os.path.join(pasta, arquivo)))
    
    # Crie o caminho completo para o arquivo REM mais recente
    cnab = os.path.join(pasta, caminho_arquivo_rem)

# Defina o caminho para o arquivo CNAB do Santander
arquivo_cnab =  cnab

# Crie uma lista para armazenar os registros lidos
cabecario = []

with open(arquivo_cnab, 'r') as arquivo:
    # Leia cada linha do arquivo
    linhas = arquivo.readlines()

    for linha in linhas[-1:]:    # Faça algo com cada linha do arquivo, por exemplo, imprima-a
        campo1 = linha[0:1]
        campo2 = linha[1:7]
        campo3 = linha[7:20]
        campo4 = linha[394:400]
        #campo1 = linha[0:1]
        


        registro = {
            'Código do Registro trailer': campo1,
            'Quantidade de registro no arquivo': campo2,
            'Valor Total dos boletos': campo3,
            'Número sequencial de registro no arquivo trailer': campo4,
            #'Código do Registro header': campo1,
            #'Código do Registro header': campo1,
            
            
            
            

 }
        
        cabecario.append(registro)

for registro in cabecario:
    print(registro)

# %%
trailer = pd.DataFrame.from_dict(cabecario)
df_resultado = pd.concat([df_resultado, trailer], axis=1)
df_resultado = df_resultado.replace({pd.NA: None, pd.NaT: None})

# %%
df_resultado['Valor Total dos boletos'] = df_resultado['Valor Total dos boletos'].str.lstrip('0')

df_resultado['Código do Registro trailer'].fillna(method='ffill', inplace=True)
df_resultado['Quantidade de registro no arquivo'].fillna(method='ffill', inplace=True)
df_resultado['Valor Total dos boletos'].fillna(method='ffill', inplace=True)
df_resultado['Número sequencial de registro no arquivo trailer'].fillna(method='ffill', inplace=True)
df_resultado = df_resultado.reset_index()

# %%
df_resultado

# %%
df_resultado['Data da Gravação do Arquivo'] = df_resultado['Data da Gravação do Arquivo'].astype(str).str.zfill(6)
df_resultado['Data da Gravação do Arquivo'] = df_resultado['Data da Gravação do Arquivo'].apply(lambda x: f"{x[:2]}/{x[2:4]}/{x[4:]}")

# %%
df_resultado = df_resultado.drop(['level_0', 'index'], axis=1)

# %%
df_resultado.to_excel("C:/Users/elean/Desktop/bancodedados/teste.xlsx")

# %%
#https://cms.santander.com.br/sites/WPS/documentos/arq-cobranca400-port/23-10-24_142650_h7800layoutdecobranca_4002023.pdf

# %%
import re

df_resultado['CODIGO DO DOC'] = df_resultado['CODIGO DO DOC'].apply(lambda x: re.sub("[^0-9]", "", str(x)))

# %%
import mysql.connector
import pandas as pd

# Seus dados de conexão
mydb = mysql.connector.connect(
    host=os.getenv('DB_HOST'),
    user=os.getenv('DB_USER'),
    password=os.getenv('DB_PASSWORD'),
    database=os.getenv('DB_NAME'),
)


# Função para inserir dados na tabela
def inserir_dados(cursor, tabela, df_resultado):
    for index, row in df_resultado.iterrows():
        placeholders = ', '.join(['%s'] * len(row))
        columns = ', '.join(f"`{col}`" for col in row.keys())
        sql = f"INSERT INTO {tabela} ({columns}) VALUES ({placeholders})"
        cursor.execute(sql, tuple(row))

# Cria um cursor para executar consultas
cursor = mydb.cursor()

# Nome da tabela no banco de dados
nome_tabela = 'remessa_santander'

# Insere os dados na tabela
inserir_dados(cursor, nome_tabela, df_resultado)

# Commit para salvar as alterações
mydb.commit()

# Fecha o cursor e a conexão
cursor.close()
mydb.close()

print("remessa salva no banco de dados!")

# %%
import shutil
pasta_destino = 'C:/Users/elean/Desktop/BANCOS/santander/lido'
shutil.move(cnab, pasta_destino)
print(f'O arquivo foi movido para {pasta_destino}')
