# %%
#ler o corpo da Remessa
import pandas as pd
import os

# Diretório onde estão os arquivos REM
pasta =  r'C:\Users\elean\Desktop\RETORNOS\retorno_safra\processados\2025'
#C:\Users\elean\Desktop\BANCOS
# Liste todos os arquivos na pasta
arquivos = os.listdir(pasta)

# Filtrar apenas os arquivos que têm a extensão .REM
arquivos_rem = [arquivo for arquivo in arquivos if arquivo.endswith('.txt')]

# Encontre o arquivo REM mais recente com base na data de modificação
if arquivos_rem:
    caminho_arquivo_rem = max(arquivos_rem, key=lambda arquivo: os.path.getmtime(os.path.join(pasta, arquivo)))
    
    # Crie o caminho completo para o arquivo REM mais recente
    cnab = os.path.join(pasta, caminho_arquivo_rem)

# Defina o caminho para o arquivo CNAB do Santander
arquivo_cnab =  cnab

# Crie uma lista para armazenar os registros lidos
cabecario = []

with open(arquivo_cnab, 'r') as arquivo:
    # Leia cada linha do arquivo
    linhas = arquivo.readlines()

    for linha in linhas[1:]:    # Faça algo com cada linha do arquivo, por exemplo, imprima-a
        campo1 = linha[0:1]
        campo2 = linha[1:3]        
        campo3 = linha[3:17]        
        campo4 = linha[37:62]        
        campo5 = linha[62:71]        
        campo6 = linha[102:104]        
        campo7 = linha[104:107]        
        campo8 = linha[107:108] 
        campo9 = linha[108:110]        
        campo10 = linha[110:116]        
        campo11 = linha[116:126]        
        campo12 = linha[126:135]        
        campo13 = linha[146:152]        
        campo14 = linha[152:165]        
        campo15 = linha[165:168]        
        campo16 = linha[168:173]        
        campo17 = linha[173:175]        
        campo18 = linha[175:188]        
        campo19 = linha[188:201]        
        campo20 = linha[214:227]        
        campo21 = linha[227:240]        
        campo22 = linha[240:253]        
        campo23 = linha[253:266]        
        campo24 = linha[266:279]        
        campo25 = linha[279:292]        
        campo26 = linha[295:301]        
        campo27 = linha[307:321]        
        campo28 = linha[321:322]        
        campo29 = linha[322:324]        
        campo30 = linha[376:391]        
        campo31 = linha[391:394]        
        campo32 = linha[395:400]        
        #campo8 = linha[107:108]        
        #campo8 = linha[107:108]        
        #campo8 = linha[107:108]        
        #campo8 = linha[107:108]        
        #campo8 = linha[107:108]        
        #campo8 = linha[107:108]        
        #campo8 = linha[107:108]        
        #campo8 = linha[107:108]        
        #campo8 = linha[107:108]        
        
        

        
        
        
        

        #campo32= linha[218:220]
        #campo32= linha[218:220]
        registro = {
            'Identificaçao Do Registro Transação': campo1,                   
            'Tipo De Inscri ão Da Empresara': campo2,             
            'Número De Inscriçao Da Empresa': campo3,             
            'CODIGO DO DOC': campo4,             
            'Identifica  o Do Título No Banco': campo5,             
            'Cod. Ocorrência Recebida No Arquivo REMESSA': campo6,             
            'Código De Motivo De Rejeição': campo7,             
            'Identificação Do Tipo De Carteira': campo8,             
            'Identifica  o Da Ocorrência (Retorno)': campo9,     
            'Data Da Ocorrência No Banco': campo10,             
            'Identifica  o Do Título Na Empresa': campo11,             
            'Nosso Número': campo12,             
            'Data De Vencimento Do Título': campo13,             
            'Valor Título': campo14,             
            'Código Do Banco Encarregado Da Cobrança': campo15,             
            'Agência Encarregada Da Cobrança': campo16,             
            'Espécie': campo17,             
            'Tarifa De Cobrança': campo18,             
            'Valor De Outras Despesas': campo19,             
            'lof': campo20,             
            'Valor Abatimento Concedido Ou Cancelado': campo21,     
            'Valor Do Desconto Concedido': campo22,             
            'Valor Líquido Pago Pelo Pagador': campo23,             
            'Juros De Mora': campo24,             
            'Valor De Outros Créditos': campo25,             
            'Data De Crédito Para Ocorrências 06, 07, 15 e 41': campo26,             
            'Código Beneficiario Transferido Ocorrência 21': campo27,             
            'indica entrada do titulo no DDA': campo28,             
            'Meio de Liquida': campo29,             
            'Seu Número': campo30,             
            'Número Seqüencial Geração Arq. Retorno': campo31,             
            'Número Seqüencial Do Registro No Arquivo': campo32,             
            #'Unidade de Federação do Pagador': campo41,             
            
            
            
            

            
            
            
 }
        
        cabecario.append(registro)

for registro in cabecario:
    print(registro)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 22
#      19     cnab = os.path.join(pasta, caminho_arquivo_rem)
#      21 # Defina o caminho para o arquivo CNAB do Santander
# ---> 22 arquivo_cnab =  cnab
#      24 # Crie uma lista para armazenar os registros lidos
#      25 cabecario = []
#
# NameError: name 'cnab' is not defined

# %%
nome_arquivo = os.path.basename(arquivo_cnab)

# %%
nome_arquivo

# %%
dados = pd.DataFrame.from_dict(cabecario)
dados = dados.drop(dados.index[-1])
dados['CODIGO DO DOC'] = dados['CODIGO DO DOC'].str.strip()

dados['CODIGO DO DOC'] = dados['CODIGO DO DOC'].str.replace(' ', '')

# %%
dados['Valor Título'] = dados['Valor Título'].str.lstrip('0')
dados['Tarifa De Cobrança'] = dados['Tarifa De Cobrança'].str.lstrip('0')
dados['Valor De Outras Despesas'] = dados['Valor De Outras Despesas'].str.lstrip('0')
dados['Valor Abatimento Concedido Ou Cancelado'] = dados['Valor Abatimento Concedido Ou Cancelado'].str.lstrip('0')
dados['Valor Do Desconto Concedido'] = dados['Valor Do Desconto Concedido'].str.lstrip('0')
dados['Valor Líquido Pago Pelo Pagador'] = dados['Valor Líquido Pago Pelo Pagador'].str.lstrip('0')
dados['Juros De Mora'] = dados['Juros De Mora'].str.lstrip('0')
dados['Valor Título'] = dados['Valor Título'].apply(lambda x: f'{str(x)[:-2]},{str(x)[-2:]}')
dados['Tarifa De Cobrança'] = dados['Tarifa De Cobrança'].apply(lambda x: f'{str(x)[:-2]},{str(x)[-2:]}')
dados['Valor De Outras Despesas'] = dados['Valor De Outras Despesas'].apply(lambda x: f'{str(x)[:-2]},{str(x)[-2:]}')
dados['Valor Abatimento Concedido Ou Cancelado'] = dados['Valor Abatimento Concedido Ou Cancelado'].apply(lambda x: f'{str(x)[:-2]},{str(x)[-2:]}')
dados['Valor Do Desconto Concedido'] = dados['Valor Do Desconto Concedido'].apply(lambda x: f'{str(x)[:-2]},{str(x)[-2:]}')
dados['Valor Líquido Pago Pelo Pagador'] = dados['Valor Líquido Pago Pelo Pagador'].apply(lambda x: f'{str(x)[:-2]},{str(x)[-2:]}')
dados['Juros De Mora']= dados['Juros De Mora'].apply(lambda x: f'{str(x)[:-2]},{str(x)[-2:]}')

# %%
dados['Nome do arquivo'] = nome_arquivo
dados['Nome do arquivo'].fillna(method='ffill', inplace=True)

# %%
dados.loc[dados['Identifica  o Da Ocorrência (Retorno)'] == '02', 'Identifica  o Da Ocorrência (Retorno)'] = "ENTRADA CONFIRMADA"
dados.loc[dados['Identifica  o Da Ocorrência (Retorno)'] == '03', 'Identifica  o Da Ocorrência (Retorno)'] = "ENTRADA REJEITADA"
dados.loc[dados['Identifica  o Da Ocorrência (Retorno)'] == '04', 'Identifica  o Da Ocorrência (Retorno)'] = "TRANSFERÊNCIA DE CARTEIRA (ENTRADA)"
dados.loc[dados['Identifica  o Da Ocorrência (Retorno)'] == '05', 'Identifica  o Da Ocorrência (Retorno)'] = "TRANSFERÊNCIA DE CARTEIRA (BAIXA)"
dados.loc[dados['Identifica  o Da Ocorrência (Retorno)'] == '06', 'Identifica  o Da Ocorrência (Retorno)'] = "LIQUIDAÇÃO NORMAL"
dados.loc[dados['Identifica  o Da Ocorrência (Retorno)'] == '09', 'Identifica  o Da Ocorrência (Retorno)'] = "BAIXADO AUTOMATICAMENTE"
dados.loc[dados['Identifica  o Da Ocorrência (Retorno)'] == '10', 'Identifica  o Da Ocorrência (Retorno)'] = "BAIXADO CONFORME  INSTRUÇÕES"
dados.loc[dados['Identifica  o Da Ocorrência (Retorno)'] == '11', 'Identifica  o Da Ocorrência (Retorno)'] = "TÍTULOS EM SER (PARA ARQUIVO MENSAL)"
dados.loc[dados['Identifica  o Da Ocorrência (Retorno)'] == '12', 'Identifica  o Da Ocorrência (Retorno)'] = "ABATIMENTO CONCEDIDO"
dados.loc[dados['Identifica  o Da Ocorrência (Retorno)'] == '13', 'Identifica  o Da Ocorrência (Retorno)'] = "ABATIMENTO CANCELADO"
dados.loc[dados['Identifica  o Da Ocorrência (Retorno)'] == '14', 'Identifica  o Da Ocorrência (Retorno)'] = "VENCIMENTO ALTERADO"
dados.loc[dados['Identifica  o Da Ocorrência (Retorno)'] == '15', 'Identifica  o Da Ocorrência (Retorno)'] = "LIQUIDAÇÃO EM CARTÓRIO"
dados.loc[dados['Identifica  o Da Ocorrência (Retorno)'] == '19', 'Identifica  o Da Ocorrência (Retorno)'] = "CONFIRMAÇÃO DE INSTRUÇÃO DE PROTESTO"
dados.loc[dados['Identifica  o Da Ocorrência (Retorno)'] == '20', 'Identifica  o Da Ocorrência (Retorno)'] = "CONFIRMAÇÃO DE SUSTAR PROTESTO"
dados.loc[dados['Identifica  o Da Ocorrência (Retorno)'] == '21', 'Identifica  o Da Ocorrência (Retorno)'] = "TRANSFERÊNCIA  DE BENEFICIÁRIO"
dados.loc[dados['Identifica  o Da Ocorrência (Retorno)'] == '23', 'Identifica  o Da Ocorrência (Retorno)'] = "TÍTULO ENVIADO A CARTÓRIO"
dados.loc[dados['Identifica  o Da Ocorrência (Retorno)'] == '40', 'Identifica  o Da Ocorrência (Retorno)'] = "BAIXA DE TÍTULO PROTESTADO"
dados.loc[dados['Identifica  o Da Ocorrência (Retorno)'] == '41', 'Identifica  o Da Ocorrência (Retorno)'] = "LIQUIDAÇÃO DE TÍTULO BAIXADO"
dados.loc[dados['Identifica  o Da Ocorrência (Retorno)'] == '42', 'Identifica  o Da Ocorrência (Retorno)'] = "TÍTULO RETIRADO DO CARTÓRIO"
dados.loc[dados['Identifica  o Da Ocorrência (Retorno)'] == '43', 'Identifica  o Da Ocorrência (Retorno)'] = "DESPESA DE CARTÓRIO"
dados.loc[dados['Identifica  o Da Ocorrência (Retorno)'] == '44', 'Identifica  o Da Ocorrência (Retorno)'] = "ACEITE DO TÍTULO DDA PELO PAGADOR"
dados.loc[dados['Identifica  o Da Ocorrência (Retorno)'] == '45', 'Identifica  o Da Ocorrência (Retorno)'] = "NÃO ACEITE DO TÍTULO DDA PELO PAGADOR"
dados.loc[dados['Identifica  o Da Ocorrência (Retorno)'] == '51', 'Identifica  o Da Ocorrência (Retorno)'] = "VALOR DO TÍTULO ALTERADO"
dados.loc[dados['Identifica  o Da Ocorrência (Retorno)'] == '52', 'Identifica  o Da Ocorrência (Retorno)'] = "ACERTO DE DATA DE EMISSAO"
dados.loc[dados['Identifica  o Da Ocorrência (Retorno)'] == '53', 'Identifica  o Da Ocorrência (Retorno)'] = "ACERTO DE COD ESPECIE DOCTO"
dados.loc[dados['Identifica  o Da Ocorrência (Retorno)'] == '54', 'Identifica  o Da Ocorrência (Retorno)'] = "ALTERACAO DE SEU NUMERO"
dados.loc[dados['Identifica  o Da Ocorrência (Retorno)'] == '56', 'Identifica  o Da Ocorrência (Retorno)'] = "INSTRUÇÃO NEGATIVAÇÃO ACEITA"
dados.loc[dados['Identifica  o Da Ocorrência (Retorno)'] == '57', 'Identifica  o Da Ocorrência (Retorno)'] = "INSTRUÇÃO BAIXA DE NEGATIVAÇÃO ACEITA"
dados.loc[dados['Identificação Do Tipo De Carteira'] == '58', 'Identifica  o Da Ocorrência (Retorno)'] = "INSTRUÇÃO NÃO NEGATIVAR  ACEITA"

# %%
dados.loc[dados['Identificação Do Tipo De Carteira'] == '1', 'Identificação Do Tipo De Carteira'] = "cobrança simples"
dados.loc[dados['Identificação Do Tipo De Carteira'] == '2', 'Identificação Do Tipo De Carteira'] = "Cobrança descontada"

# %%
dados['Identifica  o Da Ocorrência (Retorno)']

# %% [markdown]
# # header

# %%
# Filtrar apenas os arquivos que têm a extensão .REM
arquivos_rem = [arquivo for arquivo in arquivos if arquivo.endswith('.REM')]

# Encontre o arquivo REM mais recente com base na data de modificação
if arquivos_rem:
    caminho_arquivo_rem = max(arquivos_rem, key=lambda arquivo: os.path.getmtime(os.path.join(pasta, arquivo)))
    
    # Crie o caminho completo para o arquivo REM mais recente
    cnab = os.path.join(pasta, caminho_arquivo_rem)

# Defina o caminho para o arquivo CNAB do Santander
arquivo_cnab =  cnab

# Crie uma lista para armazenar os registros lidos
cabecario = []

with open(arquivo_cnab, 'r') as arquivo:
    # Leia cada linha do arquivo
    linhas = arquivo.readlines()

    for linha in linhas[0:1]:    # Faça algo com cada linha do arquivo, por exemplo, imprima-a
        campo1 = linha[0:1]
        campo2 = linha[1:2]
        campo3 = linha[2:9]
        campo4 = linha[9:11]
        campo5 = linha[11:19]
        campo6 = linha[26:40]
        campo7 = linha[46:76]
        campo8 = linha[76:79]
        campo9 = linha[79:84]
        campo10 = linha[94:100]
        campo11 = linha[391:394]
        campo12 = linha[394:400]
        #campo13 = linha[100:107]
        #campo14 = linha[107:121]
       # campo15 = linha[394:400]
        
    
        
        registro = {
            'Identificação Registro Header': campo1,
            'Identificação Arquivo Retorno Header': campo2,
            'Identificação Arquivo Retorno P/ extenso': campo3,
            'Código Identificação Do Serviço Header': campo4,
            'Identificação Do Serviço P/ Extenso': campo5,
            'Ident. Empresa No Banco': campo6,
            'Nome Da Empresa Beneficiário': campo7,    
            'Código De Identificação Do Banco': campo8,
            'Nome Do Banco Por Extenso': campo9,    
            'Data Da Geração Do Arquivo Retorno': campo10,    
            'Número Seqüencial De Geração Do Arquivo Header': campo11,      
            'Número Seqüencial Do Registro No Arquivo Header': campo12,
            #'SEQUENCIAL DO RETORNO': campo13,            
            #'CÓDIGO DO BENEFICIÁRIO CABECARIO': campo14,
            #'FIXO7': campo15,            
            
            
            
            
            
            
            
            
            
            
            
            

 }
        
        cabecario.append(registro)

for registro in cabecario:
    print(registro)

# %%
df_cabecario = pd.DataFrame.from_dict(cabecario)
df_resultado = pd.concat([dados, df_cabecario], axis=1)
df_resultado.replace('None', pd.NA, inplace=True)

# %%
# Preencher os valores nulos na coluna 'Código de Serviço' com os valores da linha anterior
df_resultado['Identificação Registro Header'].fillna(method='ffill', inplace=True) 
df_resultado['Identificação Arquivo Retorno Header'].fillna(method='ffill', inplace=True)
df_resultado['Identificação Arquivo Retorno P/ extenso'].fillna(method='ffill', inplace=True)
df_resultado['Código Identificação Do Serviço Header'].fillna(method='ffill', inplace=True)
df_resultado['Ident. Empresa No Banco'].fillna(method='ffill', inplace=True)
df_resultado['Nome Da Empresa Beneficiário'].fillna(method='ffill', inplace=True)
df_resultado['Código De Identificação Do Banco'].fillna(method='ffill', inplace=True)
df_resultado['Nome Da Empresa Beneficiário'].fillna(method='ffill', inplace=True)
df_resultado['Nome Do Banco Por Extenso'].fillna(method='ffill', inplace=True)
df_resultado['Data Da Geração Do Arquivo Retorno'].fillna(method='ffill', inplace=True)
df_resultado['Número Seqüencial De Geração Do Arquivo Header'].fillna(method='ffill', inplace=True)
df_resultado['Número Seqüencial Do Registro No Arquivo Header'].fillna(method='ffill', inplace=True)
df_resultado['Identificação Do Serviço P/ Extenso'].fillna(method='ffill', inplace=True)

# %% [markdown]
# # Trailler

# %%
# Filtrar apenas os arquivos que têm a extensão .REM

# Encontre o arquivo REM mais recente com base na data de modificação
if arquivos_rem:
    caminho_arquivo_rem = max(arquivos_rem, key=lambda arquivo: os.path.getmtime(os.path.join(pasta, arquivo)))
    
    # Crie o caminho completo para o arquivo REM mais recente
    cnab = os.path.join(pasta, caminho_arquivo_rem)

# Defina o caminho para o arquivo CNAB do Santander
arquivo_cnab =  cnab

# Crie uma lista para armazenar os registros lidos
cabecario = []

with open(arquivo_cnab, 'r') as arquivo:
    # Leia cada linha do arquivo
    linhas = arquivo.readlines()

    for linha in linhas[-1:]:    # Faça algo com cada linha do arquivo, por exemplo, imprima-a
        campo1 = linha[0:1]
        campo2 = linha[1:2]
        campo3 = linha[2:4]
        campo4 = linha[4:7]
        campo5 = linha[17:25]
        campo7 = linha[25:39]
        campo8 = linha[39:47]
        campo9 = linha[391:394]
        campo10 = linha[394:400]

        
        


        registro = {
            'Código do Registro trailer': campo1,
            'Identificação Do Arquivo Retorno treiler': campo2,
            'Código Identificação Do Serviço treiler': campo3,
            'Código De Identificação Do Banco treiler': campo4,
            'Quantidade De Títulos': campo5,
            'Valor Total Dos Títulos': campo7,
            'Número do aviso de cobrança': campo8,
            'Número Seqüencial Geração Arquivo Retorno treiler': campo9,
            'Número Seqüencial Do Registro No Arquivo treiler': campo10,

            
            
            
            
            

 }
        
        cabecario.append(registro)

for registro in cabecario:
    print(registro)

# %%
trailer = pd.DataFrame.from_dict(cabecario)
trailer =trailer[0:1]

# %%
df_resultado = pd.concat([df_resultado, trailer], axis=1)
df_resultado = df_resultado.replace({pd.NA: None, pd.NaT: None})

df_resultado['Código do Registro trailer'].fillna(method='ffill', inplace=True)
df_resultado['Identificação Do Arquivo Retorno treiler'].fillna(method='ffill', inplace=True)
df_resultado['Código Identificação Do Serviço treiler'].fillna(method='ffill', inplace=True)
df_resultado['Quantidade De Títulos'].fillna(method='ffill', inplace=True)
df_resultado['Código De Identificação Do Banco treiler'].fillna(method='ffill', inplace=True)
df_resultado['Valor Total Dos Títulos'].fillna(method='ffill', inplace=True)
df_resultado['Número do aviso de cobrança'].fillna(method='ffill', inplace=True)
df_resultado['Número Seqüencial Geração Arquivo Retorno treiler'].fillna(method='ffill', inplace=True)
df_resultado['Número Seqüencial Do Registro No Arquivo treiler'].fillna(method='ffill', inplace=True)

# %%
df_resultado

# %%
df_resultado['Data Da Ocorrência No Banco'] = pd.to_datetime(df_resultado['Data Da Ocorrência No Banco'], format='%d%m%y')
df_resultado['Data Da Ocorrência No Banco'] = df_resultado['Data Da Ocorrência No Banco'].dt.strftime('%Y-%m-%d')

#df_resultado['Data De Vencimento Do Título'] = pd.to_datetime(df_resultado['Data De Vencimento Do Título'], format='%d%m%y')
#df_resultado['Data De Vencimento Do Título'] = df_resultado['Data De Vencimento Do Título'].dt.strftime('%Y-%m-%d')

# %%
import mysql.connector
import pandas as pd

# Seus dados de conexão
mydb = mysql.connector.connect(
    host=os.getenv('DB_HOST'),
    user=os.getenv('DB_USER'),
    password=os.getenv('DB_PASSWORD'),
    database=os.getenv('DB_NAME'),
)


# Função para inserir dados na tabela
def inserir_dados(cursor, tabela, df_resultado):
    for index, row in df_resultado.iterrows():
        placeholders = ', '.join(['%s'] * len(row))
        columns = ', '.join(f"`{col}`" for col in row.keys())
        sql = f"INSERT INTO {tabela} ({columns}) VALUES ({placeholders})"
        cursor.execute(sql, tuple(row))

# Cria um cursor para executar consultas
cursor = mydb.cursor()

# Nome da tabela no banco de dados
nome_tabela = 'retorno_safra'

# Insere os dados na tabela
inserir_dados(cursor, nome_tabela, df_resultado)

# Commit para salvar as alterações
mydb.commit()

# Fecha o cursor e a conexão
cursor.close()
mydb.close()

print("remessa salva no banco de dados!")

# %%
import shutil
pasta_destino = r'C:\Users\elean\Desktop\RETORNOS\retorno_safra\lido'
shutil.move(cnab, pasta_destino)
print(f'O arquivo foi movido para {pasta_destino}')
