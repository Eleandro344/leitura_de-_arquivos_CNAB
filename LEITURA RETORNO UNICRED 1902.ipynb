# %%
#ler o corpo da Remessa
import pandas as pd
import os

# Diretório onde estão os arquivos REM
pasta =  'C:/Users/elean/Desktop/RETORNOS/retornounicred/processados/2025'

# Liste todos os arquivos na pasta
arquivos = os.listdir(pasta)

# Filtrar apenas os arquivos que têm a extensão .REM
arquivos_rem = [arquivo for arquivo in arquivos if arquivo.endswith('.RET')]

# Encontre o arquivo REM mais recente com base na data de modificação
if arquivos_rem:
    caminho_arquivo_rem = max(arquivos_rem, key=lambda arquivo: os.path.getmtime(os.path.join(pasta, arquivo)))
    
    # Crie o caminho completo para o arquivo REM mais recente
    cnab = os.path.join(pasta, caminho_arquivo_rem)

# Defina o caminho para o arquivo CNAB do Santander
arquivo_cnab =  cnab

# Crie uma lista para armazenar os registros lidos
cabecario = []

with open(arquivo_cnab, 'r') as arquivo:
    # Leia cada linha do arquivo
    linhas = arquivo.readlines()

    for linha in linhas[1:]:    # Faça algo com cada linha do arquivo, por exemplo, imprima-a
        campo1 = linha[2:3]
        campo2 = linha[3:17]
        campo3 = linha[17:21]
        campo4 = linha[21:22]
        campo5 = linha[22:30]
        campo7 = linha[30:31]        
        campo8 = linha[31:45]         
        campo9 = linha[45:62] 
        campo32 = linha[74:75] 
        campo10 = linha[85:88]         
        campo11 = linha[106:108]   
        campo12 = linha[108:110]    
        campo13 = linha[110:116] 
        campo14 = linha[116:119]
        campo15 = linha[146:152]
        campo16 = linha[152:165]
        campo17 = linha[165:168]
        campo18 = linha[168:172]  
        campo19 = linha[172:173]          
        campo20 = linha[175:181]          
        campo21 = linha[181:188]  
        campo22 = linha[188:196]  
        campo23 = linha[227:240] 
        campo24 = linha[240:253] 
        campo25 = linha[253:266]   
        campo26 = linha[266:279]
        campo27 = linha[279:305]         
        campo28 = linha[305:318]         
        campo29 = linha[318:326]
        campo30 = linha[326:328]   
        campo31 = linha[394:400] 
        
        
        
        
        #campo32= linha[218:220]
        #campo32= linha[218:220]
        registro = {
            'TIPO DE INSCRIÇÃO DA EMPRESA': campo1,
            'NÚMERO DE INSCRIÇÃO DA EMPRESA': campo2,
            'NÚMERO DA AGÊNCIA': campo3, 
            'DÍGITO VERIFICADOR DA AGÊNCIA': campo4,  
            'CONTA CORRENTE DO BENEFICIÁRIO': campo5,            
            'DÍGITO VERIFICADOR DA CONTA DO BENEFICIÁRIO': campo7,    
            'CÓDIGO DO BENEFICIÁRIO': campo8,              
            'NOSSO NÚMERO': campo9,        
            'FIXO': campo32,  
            'FIXO2': campo10, 
            'FIXO3': campo11, 
            'CÓDIGO DE MOVIMENTO': campo12,             
            'DATA LIQUIDAÇÃO': campo13, 
            'CANAL DE LIQUIDAÇÃO': campo14,             
            'DATA DE VENCIMENTO': campo15,  
            'VALOR DO TÍTULO': campo16,
            'CÓDIGO DO BANCO RECEBEDOR': campo17, 
            'PREFIXO DA AGÊNCIA RECEBEDORA': campo18,      
            'DV-PREFIXO AGÊNCIA RECEBEDORA': campo19,      
            'DATA PROGRAMADA PARA REPASSE': campo20,      
            'VALOR DA TARIFA': campo21, 
            'DATA DE DEBITO DA TARIFA': campo22, 
            'VALOR ABATIMENTO': campo23,
            'VALOR DESCONTO CONCEDIDO': campo24,  
            'VALOR PAGO': campo25,             
            'JUROS DE MORA': campo26,           
            'CODIGO DO DOC': campo27,         
            'VALOR LÍQUIDO': campo28,
            'COMPLEMENTO DO MOVIMENTO': campo29,               
            'TIPO DE INSTRUÇÃO ORIGEM': campo30,       
            'SEQUENCIAL DO REGISTRO': campo31,              
            
            
 }
        
        cabecario.append(registro)

#for registro in cabecario:
 #   print(registro)
nome_arquivo = os.path.basename(arquivo_cnab)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 22
#      19     cnab = os.path.join(pasta, caminho_arquivo_rem)
#      21 # Defina o caminho para o arquivo CNAB do Santander
# ---> 22 arquivo_cnab =  cnab
#      24 # Crie uma lista para armazenar os registros lidos
#      25 cabecario = []
#
# NameError: name 'cnab' is not defined

# %%
dados = pd.DataFrame.from_dict(cabecario)
dados = dados.drop(dados.index[-1])
dados['CODIGO DO DOC'] = dados['CODIGO DO DOC'].str.strip()

dados['CODIGO DO DOC'] = dados['CODIGO DO DOC'].str.replace(' ', '')

# %%
dados['VALOR DO TÍTULO'] = dados['VALOR DO TÍTULO'].str.lstrip('0')
dados['VALOR ABATIMENTO'] = dados['VALOR ABATIMENTO'].str.lstrip('0')
dados['VALOR DESCONTO CONCEDIDO'] = dados['VALOR DESCONTO CONCEDIDO'].str.lstrip('0')
dados['VALOR PAGO'] = dados['VALOR PAGO'].str.lstrip('0')
dados['JUROS DE MORA'] = dados['JUROS DE MORA'].str.lstrip('0')
dados['VALOR LÍQUIDO'] = dados['VALOR LÍQUIDO'].str.lstrip('0')
dados['VALOR DO TÍTULO'] = dados['VALOR DO TÍTULO'].apply(lambda x: f'{str(x)[:-2]},{str(x)[-2:]}')
dados['VALOR ABATIMENTO'] = dados['VALOR ABATIMENTO'].apply(lambda x: f'{str(x)[:-2]},{str(x)[-2:]}')
dados['VALOR DESCONTO CONCEDIDO'] = dados['VALOR DESCONTO CONCEDIDO'].apply(lambda x: f'{str(x)[:-2]},{str(x)[-2:]}')
dados['VALOR PAGO'] = dados['VALOR PAGO'].apply(lambda x: f'{str(x)[:-2]},{str(x)[-2:]}')
dados['JUROS DE MORA'] = dados['JUROS DE MORA'].apply(lambda x: f'{str(x)[:-2]},{str(x)[-2:]}')
dados['VALOR LÍQUIDO'] = dados['VALOR LÍQUIDO'].apply(lambda x: f'{str(x)[:-2]},{str(x)[-2:]}')

# %%
dados['Nome do arquivo'] = nome_arquivo
dados['Nome do arquivo'].fillna(method='ffill', inplace=True)

# %%
nome_arquivo

# %%
dados

# %%
#INSTRUÇÕES DE ENTRADA

dados.loc[dados['CÓDIGO DE MOVIMENTO'] == '02', 'CÓDIGO DE MOVIMENTO'] = "Instrução Confirmada"
dados.loc[dados['CÓDIGO DE MOVIMENTO'] == '01', 'CÓDIGO DE MOVIMENTO'] = "Pago(Título protestado pago em cartório)"
dados.loc[dados['CÓDIGO DE MOVIMENTO'] == '03', 'CÓDIGO DE MOVIMENTO'] = "Instrução Rejeitada"
dados.loc[dados['CÓDIGO DE MOVIMENTO'] == '04', 'CÓDIGO DE MOVIMENTO'] = "Sustado Judicial (Título protestado sustado judicialmente)"
dados.loc[dados['CÓDIGO DE MOVIMENTO'] == '06', 'CÓDIGO DE MOVIMENTO'] = "Liquidação Normal"
dados.loc[dados['CÓDIGO DE MOVIMENTO'] == '07', 'CÓDIGO DE MOVIMENTO'] = "Liquidação em Condicional (Título liquidado em cartório com cheque do próprio devedor)"
dados.loc[dados['CÓDIGO DE MOVIMENTO'] == '08', 'CÓDIGO DE MOVIMENTO'] = "Sustado Definitivo (Título protestado sustado judicialmente)"
dados.loc[dados['CÓDIGO DE MOVIMENTO'] == '09', 'CÓDIGO DE MOVIMENTO'] = "Liquidação de Título Descontado"
dados.loc[dados['CÓDIGO DE MOVIMENTO'] == '10', 'CÓDIGO DE MOVIMENTO'] = "Protesto solicitado"
dados.loc[dados['CÓDIGO DE MOVIMENTO'] == '11', 'CÓDIGO DE MOVIMENTO'] = "Protesto Em cartório"
dados.loc[dados['CÓDIGO DE MOVIMENTO'] == '12', 'CÓDIGO DE MOVIMENTO'] = "Sustação solicitada"
dados.loc[dados['CÓDIGO DE MOVIMENTO'] == '13', 'CÓDIGO DE MOVIMENTO'] = "Título Descontado"
dados.loc[dados['CÓDIGO DE MOVIMENTO'] == '14', 'CÓDIGO DE MOVIMENTO'] = "Título Descontável (título com desistência de garantia em operação de desconto)"
dados.loc[dados['CÓDIGO DE MOVIMENTO'] == '15', 'CÓDIGO DE MOVIMENTO'] = "Enviada Negativação"
dados.loc[dados['CÓDIGO DE MOVIMENTO'] == '16', 'CÓDIGO DE MOVIMENTO'] = "Enviada Sustação Negativação"

# %%
#FORMA DE PAGAMENTO
dados.loc[dados['CANAL DE LIQUIDAÇÃO'] == '000', 'CANAL DE LIQUIDAÇÃO'] = "Sem informação relevante"
dados.loc[dados['CANAL DE LIQUIDAÇÃO'] == '161', 'CANAL DE LIQUIDAÇÃO'] = "Internet Banking"
dados.loc[dados['CANAL DE LIQUIDAÇÃO'] == '162', 'CANAL DE LIQUIDAÇÃO'] = "ATM"
dados.loc[dados['CANAL DE LIQUIDAÇÃO'] == '163', 'CANAL DE LIQUIDAÇÃO'] = "Caixa"
dados.loc[dados['CANAL DE LIQUIDAÇÃO'] == '164', 'CANAL DE LIQUIDAÇÃO'] = "Retaguarda"
dados.loc[dados['CANAL DE LIQUIDAÇÃO'] == '164', 'CANAL DE LIQUIDAÇÃO'] = "Monitor de TED"
dados.loc[dados['CANAL DE LIQUIDAÇÃO'] == '166', 'CANAL DE LIQUIDAÇÃO'] = "Compe"
dados.loc[dados['CANAL DE LIQUIDAÇÃO'] == '167', 'CANAL DE LIQUIDAÇÃO'] = "DDA"
dados.loc[dados['CANAL DE LIQUIDAÇÃO'] == '168', 'CANAL DE LIQUIDAÇÃO'] = "Banco Correspondente"
dados.loc[dados['CANAL DE LIQUIDAÇÃO'] == '169', 'CANAL DE LIQUIDAÇÃO'] = "Lotérica"
dados.loc[dados['CANAL DE LIQUIDAÇÃO'] == '234', 'CANAL DE LIQUIDAÇÃO'] = "Agendamento"
dados.loc[dados['CANAL DE LIQUIDAÇÃO'] == '268', 'CANAL DE LIQUIDAÇÃO'] = "Mobile"
dados.loc[dados['CANAL DE LIQUIDAÇÃO'] == '308', 'CANAL DE LIQUIDAÇÃO'] = "Cartório"
dados.loc[dados['CANAL DE LIQUIDAÇÃO'] == '333', 'CANAL DE LIQUIDAÇÃO'] = "Pix"

# %%
#COMPLEMENTO
dados['COMPLEMENTO DO MOVIMENTO']= dados['COMPLEMENTO DO MOVIMENTO'].str.strip()
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '01', 'COMPLEMENTO DO MOVIMENTO'] = "Código do Banco Inválido"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '00', 'COMPLEMENTO DO MOVIMENTO'] = "Sem Complemento a informar"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '04', 'COMPLEMENTO DO MOVIMENTO'] = "Código de Movimento não permitido para a carteira"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '05', 'COMPLEMENTO DO MOVIMENTO'] = "Código de Movimento Inválido"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '06', 'COMPLEMENTO DO MOVIMENTO'] = "Número de Inscrição do Beneficiário Inválido"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '07', 'COMPLEMENTO DO MOVIMENTO'] = "Agência - Conta Inválida"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '08', 'COMPLEMENTO DO MOVIMENTO'] = "Nosso Número Inválido"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '09', 'COMPLEMENTO DO MOVIMENTO'] = "Nosso Número Duplicado"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '10', 'COMPLEMENTO DO MOVIMENTO'] = "Carteira inválida"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '12', 'COMPLEMENTO DO MOVIMENTO'] = "Tipo de Documento Inválido"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '15', 'COMPLEMENTO DO MOVIMENTO'] = "Data de Vencimento inferior a 5 dias uteis para remessa gráfica"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '16', 'COMPLEMENTO DO MOVIMENTO'] = "Data de Vencimento Inválida"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '17', 'COMPLEMENTO DO MOVIMENTO'] = "Data de Vencimento Anterior à Data de Emissão"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '18', 'COMPLEMENTO DO MOVIMENTO'] = "Vencimento fora do Prazo de Operação"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '20', 'COMPLEMENTO DO MOVIMENTO'] = "Valor do Título Inválido"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '24', 'COMPLEMENTO DO MOVIMENTO'] = " Data de Emissão Inválida"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '25', 'COMPLEMENTO DO MOVIMENTO'] = "Data de Emissão Posterior à data de Entrega"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '26', 'COMPLEMENTO DO MOVIMENTO'] = "Código de juros inválido"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '27', 'COMPLEMENTO DO MOVIMENTO'] = "Valor de juros inválido"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '28', 'COMPLEMENTO DO MOVIMENTO'] = "Código de Desconto inválido"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '29', 'COMPLEMENTO DO MOVIMENTO'] = "Valor de Desconto inválido"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '30', 'COMPLEMENTO DO MOVIMENTO'] = "Alteração de Dados Rejeitada"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '33', 'COMPLEMENTO DO MOVIMENTO'] = "Valor de Abatimento Inválido"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '34', 'COMPLEMENTO DO MOVIMENTO'] = " Valor do Abatimento Maior ou Igual ao Valor do título"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '37', 'COMPLEMENTO DO MOVIMENTO'] = "Código para Protesto Inválido (Protesto via SGR, não é CRA)"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '38', 'COMPLEMENTO DO MOVIMENTO'] = "Prazo para Protesto Inválido (Protesto via SGR, não é CRA)"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '39', 'COMPLEMENTO DO MOVIMENTO'] = "Pedido de Protesto Não Permitido para o Título"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '40', 'COMPLEMENTO DO MOVIMENTO'] = "Título com Ordem de Protesto Emitida"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '41', 'COMPLEMENTO DO MOVIMENTO'] = "Pedido de Cancelamento"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '45', 'COMPLEMENTO DO MOVIMENTO'] = "Nome do Pagador não informado"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '46', 'COMPLEMENTO DO MOVIMENTO'] = "Número de Inscrição do Pagador Inválido"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '47', 'COMPLEMENTO DO MOVIMENTO'] = "Endereço do Pagador Não Informado"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '48', 'COMPLEMENTO DO MOVIMENTO'] = "CEP Inválido"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '49', 'COMPLEMENTO DO MOVIMENTO'] = "Titulo em processo de Protesto, não pode ser baixado por Decurso de Prazo"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '52', 'COMPLEMENTO DO MOVIMENTO'] = "Unidade Federativa Inválida"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '57', 'COMPLEMENTO DO MOVIMENTO'] = "Código de Multa inválido"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '58', 'COMPLEMENTO DO MOVIMENTO'] = "Data de Multa inválido"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '59', 'COMPLEMENTO DO MOVIMENTO'] = "Valor / percentual de Multa inválido"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '60', 'COMPLEMENTO DO MOVIMENTO'] = "Movimento para Título não Cadastrado"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '63', 'COMPLEMENTO DO MOVIMENTO'] = "Entrada para Título já cadastrado"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '79', 'COMPLEMENTO DO MOVIMENTO'] = "Data de Juros inválida"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '80', 'COMPLEMENTO DO MOVIMENTO'] = "Data de Desconto inválida"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '86', 'COMPLEMENTO DO MOVIMENTO'] = "Seu Número Inválido"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == 'A5', 'COMPLEMENTO DO MOVIMENTO'] = "Título Liquidado"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == 'A8', 'COMPLEMENTO DO MOVIMENTO'] = "Valor do Abatimento Inválido para Cancelamento"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == 'C0', 'COMPLEMENTO DO MOVIMENTO'] = " Sistema Intermitente – Entre em contato com sua Cooperativa;"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == 'C1', 'COMPLEMENTO DO MOVIMENTO'] = "Situação do título Aberto"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == 'C3', 'COMPLEMENTO DO MOVIMENTO'] = "Status do Borderô Inválido"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == 'C4', 'COMPLEMENTO DO MOVIMENTO'] = "Nome do Beneficiário Inválido;"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == 'C5', 'COMPLEMENTO DO MOVIMENTO'] = "Documento Inválido"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == 'C6', 'COMPLEMENTO DO MOVIMENTO'] = "Instrução não Atualiza Cadastro do Título"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == 'C7', 'COMPLEMENTO DO MOVIMENTO'] = "Título não registrado na CIP"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == 'C8', 'COMPLEMENTO DO MOVIMENTO'] = "Situação do Borderô inválida"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == 'C9', 'COMPLEMENTO DO MOVIMENTO'] = "Título inválido conforme situação CIP"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == 'C10', 'COMPLEMENTO DO MOVIMENTO'] = "Protesto"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == 'D0', 'COMPLEMENTO DO MOVIMENTO'] = " Beneficiário não autorizado a operar com produto Desconto"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == 'D1', 'COMPLEMENTO DO MOVIMENTO'] = "Alteração de status de desconto não permitido para título"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == 'D2', 'COMPLEMENTO DO MOVIMENTO'] = "Operação de desconto não permitida para título vencido"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == 'D3', 'COMPLEMENTO DO MOVIMENTO'] = "Alteração de status de desconto não permitido para situação do título"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == 'E0', 'COMPLEMENTO DO MOVIMENTO'] = "CEP indicado para o endereço do Pagador não compatível com os Correios"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == 'E1', 'COMPLEMENTO DO MOVIMENTO'] = "Logradouro para o endereço do Pagador não compatível com os Correios, para o CEP indicado"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == 'E2', 'COMPLEMENTO DO MOVIMENTO'] = "Tipo de logradouro para o endereço do Pagador não compatível com os Correios, para o CEP indicado"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == 'E3', 'COMPLEMENTO DO MOVIMENTO'] = " Bairro para o endereço do Pagador não compatível com os Correios, para o CEP indicado;"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == 'E4', 'COMPLEMENTO DO MOVIMENTO'] = "Cidade para o endereço do Pagador não compatível com os Correios, para o CEP indicado"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == 'E5', 'COMPLEMENTO DO MOVIMENTO'] = "UF para o endereço do Pagador não compatível com os Correios, para o CEP indicado;"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == 'E6', 'COMPLEMENTO DO MOVIMENTO'] = "Dados do segmento/registro opcional de endereço do pagador, incompletos no arquivo remessa;"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == 'E7', 'COMPLEMENTO DO MOVIMENTO'] = "Beneficiário não autorizado a enviar boleto por e-mail;"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == 'E8','COMPLEMENTO DO MOVIMENTO'] = "Indicativo para pagador receber boleto por e-mail sinalizado, porém sem o endereço do e-mail"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == 'E9', 'COMPLEMENTO DO MOVIMENTO'] = "Beneficiário não autorizado a enviar títulos para protesto"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == 'E10', 'COMPLEMENTO DO MOVIMENTO'] = "Instrução ‘09 – Protestar"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == 'E11', 'COMPLEMENTO DO MOVIMENTO'] = "Instrução 26 – Protesto Automático"
dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == 'E12', 'COMPLEMENTO DO MOVIMENTO'] = "Cancelamento de protesto automático não permitido"
#dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '52', 'COMPLEMENTO DO MOVIMENTO'] = "Unidade Federativa Inválida"
#dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '52', 'COMPLEMENTO DO MOVIMENTO'] = "Unidade Federativa Inválida"
#dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '52', 'COMPLEMENTO DO MOVIMENTO'] = "Unidade Federativa Inválida"
#dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '52', 'COMPLEMENTO DO MOVIMENTO'] = "Unidade Federativa Inválida"
#dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '52', 'COMPLEMENTO DO MOVIMENTO'] = "Unidade Federativa Inválida"
#dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '52', 'COMPLEMENTO DO MOVIMENTO'] = "Unidade Federativa Inválida"
#dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '52', 'COMPLEMENTO DO MOVIMENTO'] = "Unidade Federativa Inválida"
#dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '52', 'COMPLEMENTO DO MOVIMENTO'] = "Unidade Federativa Inválida"
#dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '52', 'COMPLEMENTO DO MOVIMENTO'] = "Unidade Federativa Inválida"
#dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '52', 'COMPLEMENTO DO MOVIMENTO'] = "Unidade Federativa Inválida"
#dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '52', 'COMPLEMENTO DO MOVIMENTO'] = "Unidade Federativa Inválida"
#dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '52', 'COMPLEMENTO DO MOVIMENTO'] = "Unidade Federativa Inválida"
#dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '52', 'COMPLEMENTO DO MOVIMENTO'] = "Unidade Federativa Inválida"
#dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '52', 'COMPLEMENTO DO MOVIMENTO'] = "Unidade Federativa Inválida"
#dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '52', 'COMPLEMENTO DO MOVIMENTO'] = "Unidade Federativa Inválida"
#dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '52', 'COMPLEMENTO DO MOVIMENTO'] = "Unidade Federativa Inválida"
#dados.loc[dados['COMPLEMENTO DO MOVIMENTO'] == '52', 'COMPLEMENTO DO MOVIMENTO'] = "Unidade Federativa Inválida"

# %%
#TIPOS DE INSTRUÇÃO DE ORIGEM


dados.loc[dados['TIPO DE INSTRUÇÃO ORIGEM'] == '00','TIPO DE INSTRUÇÃO ORIGEM'] = "Sem Tipo de Instrução Origem a informar"
dados.loc[dados['TIPO DE INSTRUÇÃO ORIGEM'] == '01','TIPO DE INSTRUÇÃO ORIGEM'] = "Remessa"
dados.loc[dados['TIPO DE INSTRUÇÃO ORIGEM'] == '02','TIPO DE INSTRUÇÃO ORIGEM'] = " Pedido de Baixa"
dados.loc[dados['TIPO DE INSTRUÇÃO ORIGEM'] == '04','TIPO DE INSTRUÇÃO ORIGEM'] = "Concessão de Abatimento"
dados.loc[dados['TIPO DE INSTRUÇÃO ORIGEM'] == '05','TIPO DE INSTRUÇÃO ORIGEM'] = "Cancelamento de Abatimento"
dados.loc[dados['TIPO DE INSTRUÇÃO ORIGEM'] == '06','TIPO DE INSTRUÇÃO ORIGEM'] = "Alteração de vencimento"
dados.loc[dados['TIPO DE INSTRUÇÃO ORIGEM'] == '09','TIPO DE INSTRUÇÃO ORIGEM'] = "Protestar"
dados.loc[dados['TIPO DE INSTRUÇÃO ORIGEM'] == '10','TIPO DE INSTRUÇÃO ORIGEM'] = "Baixa por Decurso de Prazo"
dados.loc[dados['TIPO DE INSTRUÇÃO ORIGEM'] == '11','TIPO DE INSTRUÇÃO ORIGEM'] = "Sustar Protesto e Manter em Carteira"
dados.loc[dados['TIPO DE INSTRUÇÃO ORIGEM'] == '22','TIPO DE INSTRUÇÃO ORIGEM'] = "Alteração do Seu Número"
dados.loc[dados['TIPO DE INSTRUÇÃO ORIGEM'] == '23','TIPO DE INSTRUÇÃO ORIGEM'] = "Alteração de dados do Pagador"
dados.loc[dados['TIPO DE INSTRUÇÃO ORIGEM'] == '25','TIPO DE INSTRUÇÃO ORIGEM'] = "Sustar Protesto e Baixar Título"
dados.loc[dados['TIPO DE INSTRUÇÃO ORIGEM'] == '26','TIPO DE INSTRUÇÃO ORIGEM'] = "Protesto automático"
dados.loc[dados['TIPO DE INSTRUÇÃO ORIGEM'] == '27','TIPO DE INSTRUÇÃO ORIGEM'] = "Negativação automática"
dados.loc[dados['TIPO DE INSTRUÇÃO ORIGEM'] == '40','TIPO DE INSTRUÇÃO ORIGEM'] = "Alteração de Status Desconto"
dados.loc[dados['TIPO DE INSTRUÇÃO ORIGEM'] == '45','TIPO DE INSTRUÇÃO ORIGEM'] = "Negativar"
dados.loc[dados['TIPO DE INSTRUÇÃO ORIGEM'] == '46','TIPO DE INSTRUÇÃO ORIGEM'] = " Sustar Negativação e Manter Título em Carteira"
dados.loc[dados['TIPO DE INSTRUÇÃO ORIGEM'] == '47','TIPO DE INSTRUÇÃO ORIGEM'] = "Sustar Negativação e Baixar Título "

# %%
# Filtrar apenas os arquivos que têm a extensão .REM
arquivos_rem = [arquivo for arquivo in arquivos if arquivo.endswith('.REM')]

# Encontre o arquivo REM mais recente com base na data de modificação
if arquivos_rem:
    caminho_arquivo_rem = max(arquivos_rem, key=lambda arquivo: os.path.getmtime(os.path.join(pasta, arquivo)))
    
    # Crie o caminho completo para o arquivo REM mais recente
    cnab = os.path.join(pasta, caminho_arquivo_rem)

# Defina o caminho para o arquivo CNAB do Santander
arquivo_cnab =  cnab

# Crie uma lista para armazenar os registros lidos
cabecario = []

with open(arquivo_cnab, 'r') as arquivo:
    # Leia cada linha do arquivo
    linhas = arquivo.readlines()

    for linha in linhas[0:1]:    # Faça algo com cada linha do arquivo, por exemplo, imprima-a
        campo1 = linha[0:1]
        campo2 = linha[1:2]
        campo3 = linha[2:9]
        campo4 = linha[9:11]
        campo5 = linha[11:19]
        campo6 = linha[26:30]
        campo7 = linha[30:31]
        campo8 = linha[31:39]
        campo9 = linha[39:40]
        campo10 = linha[46:76]
        campo11 = linha[76:94]
        campo12 = linha[94:100]
        campo13 = linha[100:107]
        campo14 = linha[107:121]
        campo15 = linha[394:400]
        
    
        
        registro = {
            'FIXO cabecario': campo1,
            'FIXO2 cabecario': campo2,
            'FIXO3 cabecario': campo3,
            'FIXO4': campo4,
            'FIXO5': campo5,
            'NÚMERO DA AGÊNCIA CABECARIO': campo6,
            'DÍGITO VERIFICADOR DA AGÊNCIA CABECARIO': campo7,    
            'CONTA CORRENTE DO BENEFICIÁRIO CABECARIO': campo8,
            'DÍGITO VERIFICADOR DA CONTA DO BENEFICIÁRIO CABECARIO': campo9,    
            'NOME DO BENEFICIÁRIO': campo10,    
            'FIXO6': campo11,      
            'DATA DA GERAÇÃO DO ARQUIVO': campo12,
            'SEQUENCIAL DO RETORNO': campo13,            
            'CÓDIGO DO BENEFICIÁRIO CABECARIO': campo14,
            'FIXO7': campo15,            
            
            
            
            
            
            
            
            
            
            
            
            

 }
        
        cabecario.append(registro)

for registro in cabecario:
    print(registro)

# %%
df_cabecario = pd.DataFrame.from_dict(cabecario)
df_resultado = pd.concat([dados, df_cabecario], axis=1)

# %%
df_resultado.replace('None', pd.NA, inplace=True)

# Preencher os valores nulos na coluna 'Código de Serviço' com os valores da linha anterior
df_resultado['FIXO cabecario'].fillna(method='ffill', inplace=True)
df_resultado['FIXO2 cabecario'].fillna(method='ffill', inplace=True)
df_resultado['FIXO3 cabecario'].fillna(method='ffill', inplace=True)
df_resultado['FIXO4'].fillna(method='ffill', inplace=True)
df_resultado['FIXO5'].fillna(method='ffill', inplace=True)
df_resultado['NÚMERO DA AGÊNCIA CABECARIO'].fillna(method='ffill', inplace=True)
df_resultado['DÍGITO VERIFICADOR DA AGÊNCIA CABECARIO'].fillna(method='ffill', inplace=True)
df_resultado['CONTA CORRENTE DO BENEFICIÁRIO CABECARIO'].fillna(method='ffill', inplace=True)
df_resultado['DÍGITO VERIFICADOR DA CONTA DO BENEFICIÁRIO CABECARIO'].fillna(method='ffill', inplace=True)
df_resultado['NOME DO BENEFICIÁRIO'].fillna(method='ffill', inplace=True)
df_resultado['FIXO6'].fillna(method='ffill', inplace=True)
df_resultado['DATA DA GERAÇÃO DO ARQUIVO'].fillna(method='ffill', inplace=True)
df_resultado['SEQUENCIAL DO RETORNO'].fillna(method='ffill', inplace=True)
df_resultado['CÓDIGO DO BENEFICIÁRIO CABECARIO'].fillna(method='ffill', inplace=True)
df_resultado['FIXO7'].fillna(method='ffill', inplace=True)

# %%
# Filtrar apenas os arquivos que têm a extensão .REM
arquivos_rem = [arquivo for arquivo in arquivos if arquivo.endswith('.REM')]

# Encontre o arquivo REM mais recente com base na data de modificação
if arquivos_rem:
    caminho_arquivo_rem = max(arquivos_rem, key=lambda arquivo: os.path.getmtime(os.path.join(pasta, arquivo)))
    
    # Crie o caminho completo para o arquivo REM mais recente
    cnab = os.path.join(pasta, caminho_arquivo_rem)

# Defina o caminho para o arquivo CNAB do Santander
arquivo_cnab =  cnab

# Crie uma lista para armazenar os registros lidos
cabecario = []

with open(arquivo_cnab, 'r') as arquivo:
    # Leia cada linha do arquivo
    linhas = arquivo.readlines()

    for linha in linhas[-1]:    # Faça algo com cada linha do arquivo, por exemplo, imprima-a
        campo1 = linha[0:1]


        registro = {
            'Identificação do Registro treiler': campo1,
 
 }
        
        cabecario.append(registro)

#for registro in cabecario:
 #   print(registro)

# %%
trailer = pd.DataFrame.from_dict(cabecario)
trailer =trailer[0:1]

# %%
df_resultado = pd.concat([df_resultado, trailer], axis=1)
df_resultado = df_resultado.replace({pd.NA: None, pd.NaT: None})

df_resultado['Identificação do Registro treiler'].fillna(method='ffill', inplace=True)

# %%
df_resultado = df_resultado.reset_index()

# %%
df_resultado = df_resultado.drop(['index', 'index'], axis=1)

# %%
df_resultado['DATA DA GERAÇÃO DO ARQUIVO']

# %%
df_resultado['DATA DA GERAÇÃO DO ARQUIVO'] = pd.to_datetime(df_resultado['DATA DA GERAÇÃO DO ARQUIVO'], format='%d%m%y')
df_resultado['DATA DA GERAÇÃO DO ARQUIVO'] = df_resultado['DATA DA GERAÇÃO DO ARQUIVO'].dt.strftime('%Y-%m-%d')

# %%
import re

df_resultado['CODIGO DO DOC'] = df_resultado['CODIGO DO DOC'].apply(lambda x: re.sub("[^0-9]", "", str(x)))

# %%
import mysql.connector
import pandas as pd

# Seus dados de conexão
mydb = mysql.connector.connect(
    host=os.getenv('DB_HOST'),
    user=os.getenv('DB_USER'),
    password=os.getenv('DB_PASSWORD'),
    database=os.getenv('DB_NAME'),
)


# Função para inserir dados na tabela
def inserir_dados(cursor, tabela, df_resultado):
    for index, row in df_resultado.iterrows():
        placeholders = ', '.join(['%s'] * len(row))
        columns = ', '.join(f"`{col}`" for col in row.keys())
        sql = f"INSERT INTO {tabela} ({columns}) VALUES ({placeholders})"
        cursor.execute(sql, tuple(row))

# Cria um cursor para executar consultas
cursor = mydb.cursor()

# Nome da tabela no banco de dados
nome_tabela = 'retornounicred'

# Insere os dados na tabela
inserir_dados(cursor, nome_tabela, df_resultado)

# Commit para salvar as alterações
mydb.commit()

# Fecha o cursor e a conexão
cursor.close()
mydb.close()

print("remessa salva no banco de dados!")

# %%
import shutil

# Caminho do arquivo CNAB

# Pasta de destino
pasta_destino = 'C:/Users/elean/Desktop/RETORNOS/retornounicred/retorno_lido/'

# Movendo o arquivo
shutil.move(arquivo_cnab, pasta_destino)
print(f'O arquivo foi movido para {pasta_destino}')
